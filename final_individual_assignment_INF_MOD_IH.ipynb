# %%
pip install requests beautifulsoup4
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (4.13.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2025.10.5)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4) (4.15.0)

# %%
# !apt-get update -y
# !apt-get install -y tesseract-ocr tesseract-ocr-lit poppler-utils libreoffice
# !pip install -q pytesseract pdf2image pdfminer.six PyMuPDF python-docx docx2txt pillow lxml python-slugify chardet
# Out:
# Get:1 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:2 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:3 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:4 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:9 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,287 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Hit:11 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:13 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,374 kB]
# Get:14 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,812 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/multiverse amd64 Packages [69.2 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [5,988 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,778 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,594 kB]
# Fetched 25.3 MB in 6s (4,259 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# The following additional packages will be installed:
#   apparmor default-jre default-jre-headless dictionaries-common
#   firebird3.0-common firebird3.0-common-doc firebird3.0-server-core
#   firebird3.0-utils fonts-crosextra-caladea fonts-crosextra-carlito
#   fonts-dejavu fonts-dejavu-core fonts-dejavu-extra fonts-liberation2
#   fonts-linuxlibertine fonts-noto-core fonts-noto-extra fonts-noto-mono
#   fonts-noto-ui-core fonts-opensymbol fonts-sil-gentium
#   fonts-sil-gentium-basic gstreamer1.0-gl gstreamer1.0-gtk3 hunspell-en-us
#   libabsl20210324 libabw-0.1-1 libatk-wrapper-java libatk-wrapper-java-jni
#   libbsh-java libcdr-0.1-1 libclucene-contribs1v5 libclucene-core1v5
#   libcolamd2 libe-book-0.1-1 libel-api-java libeot0 libepubgen-0.1-1
#   libetonyek-0.1-1 libexttextcat-2.0-0 libexttextcat-data libfbclient2
#   libfreehand-0.1-1 libgpgme11 libgpgmepp6 libgstreamer-gl1.0-0 libgudev-1.0-0
#   libharfbuzz-icu0 libhsqldb1.8.0-java libhunspell-1.7-0 libhyphen0 libib-util
#   libjsp-api-java liblangtag-common liblangtag1 liblibreoffice-java libmhash2
#   libmspub-0.1-1 libmwaw-0.3-3 libmythes-1.2-0 libodfgen-0.1-1 liborcus-0.17-0
#   liborcus-parser-0.17-0 libpagemaker-0.0-0 libraptor2-0 librasqal3 librdf0
#   libreoffice-base libreoffice-base-core libreoffice-base-drivers
#   libreoffice-calc libreoffice-common libreoffice-core libreoffice-draw
#   libreoffice-gnome libreoffice-gtk3 libreoffice-impress
#   libreoffice-java-common libreoffice-math libreoffice-nlpsolver
#   libreoffice-report-builder libreoffice-report-builder-bin
#   libreoffice-script-provider-bsh libreoffice-script-provider-js
#   libreoffice-script-provider-python libreoffice-sdbc-firebird
#   libreoffice-sdbc-hsqldb libreoffice-sdbc-mysql libreoffice-sdbc-postgresql
#   libreoffice-style-colibre libreoffice-style-elementary
#   libreoffice-style-yaru libreoffice-wiki-publisher libreoffice-writer
#   librevenge-0.0-0 libservlet-api-java libservlet3.1-java
#   libsuitesparseconfig5 libtext-iconv-perl libtommath1 libuno-cppu3
#   libuno-cppuhelpergcc3-3 libuno-purpenvhelpergcc3-3 libuno-sal3
#   libuno-salhelpergcc3-3 libunoloader-java libvisio-0.1-1
#   libwebsocket-api-java libwpd-0.10-10 libwpg-0.3-3 libwps-0.4-4 libxmlsec1
#   libxmlsec1-nss libxtst6 libxxf86dga1 libyajl2 lp-solve openjdk-11-jre
#   poppler-data python3-uno uno-libs-private ure ure-java x11-utils
# Suggested packages:
#   apparmor-profiles-extra apparmor-utils ispell | aspell | hunspell wordlist
#   firebird3.0-server firebird3.0-doc hunspell openoffice.org-hunspell
#   | openoffice.org-core java-virtual-machine libhsqldb1.8.0-java-gcj
#   raptor2-utils rasqal-utils librdf-storage-postgresql librdf-storage-mysql
#   librdf-storage-sqlite librdf-storage-virtuoso redland-utils cups-bsd firefox
#   | firefox-esr | thunderbird ghostscript gpa hyphen-hyphenation-patterns
#   imagemagick | graphicsmagick-imagemagick-compat libreoffice-grammarcheck
#   libreoffice-help libreoffice-l10n libreoffice-librelogo myspell-dictionary
#   mythes-thesaurus openclipart-libreoffice pstoedit unixodbc
#   gstreamer1.0-plugins-base gstreamer1.0-plugins-good
#   gstreamer1.0-plugins-ugly gstreamer1.0-plugins-bad gstreamer1.0-libav
#   libsane1 libofficebean-java libjtds-java libsqliteodbc | tdsodbc
#   | odbc-mdbtools libreoffice-evolution seahorse libreofficekit-data bluez
#   default-mysql-server | virtual-mysql-server postgresql mediawiki
#   fonts-japanese-mincho | fonts-ipafont-mincho fonts-japanese-gothic
#   | fonts-ipafont-gothic fonts-arphic-ukai fonts-arphic-uming fonts-nanum
#   mesa-utils
# The following NEW packages will be installed:
#   apparmor default-jre default-jre-headless dictionaries-common
#   firebird3.0-common firebird3.0-common-doc firebird3.0-server-core
#   firebird3.0-utils fonts-crosextra-caladea fonts-crosextra-carlito
#   fonts-dejavu fonts-dejavu-core fonts-dejavu-extra fonts-liberation2
#   fonts-linuxlibertine fonts-noto-core fonts-noto-extra fonts-noto-mono
#   fonts-noto-ui-core fonts-opensymbol fonts-sil-gentium
#   fonts-sil-gentium-basic gstreamer1.0-gl gstreamer1.0-gtk3 hunspell-en-us
#   libabsl20210324 libabw-0.1-1 libatk-wrapper-java libatk-wrapper-java-jni
#   libbsh-java libcdr-0.1-1 libclucene-contribs1v5 libclucene-core1v5
#   libcolamd2 libe-book-0.1-1 libel-api-java libeot0 libepubgen-0.1-1
#   libetonyek-0.1-1 libexttextcat-2.0-0 libexttextcat-data libfbclient2
#   libfreehand-0.1-1 libgpgme11 libgpgmepp6 libgstreamer-gl1.0-0 libgudev-1.0-0
#   libharfbuzz-icu0 libhsqldb1.8.0-java libhunspell-1.7-0 libhyphen0 libib-util
#   libjsp-api-java liblangtag-common liblangtag1 liblibreoffice-java libmhash2
#   libmspub-0.1-1 libmwaw-0.3-3 libmythes-1.2-0 libodfgen-0.1-1 liborcus-0.17-0
#   liborcus-parser-0.17-0 libpagemaker-0.0-0 libraptor2-0 librasqal3 librdf0
#   libreoffice libreoffice-base libreoffice-base-core libreoffice-base-drivers
#   libreoffice-calc libreoffice-common libreoffice-core libreoffice-draw
#   libreoffice-gnome libreoffice-gtk3 libreoffice-impress
#   libreoffice-java-common libreoffice-math libreoffice-nlpsolver
#   libreoffice-report-builder libreoffice-report-builder-bin
#   libreoffice-script-provider-bsh libreoffice-script-provider-js
#   libreoffice-script-provider-python libreoffice-sdbc-firebird
#   libreoffice-sdbc-hsqldb libreoffice-sdbc-mysql libreoffice-sdbc-postgresql
#   libreoffice-style-colibre libreoffice-style-elementary
#   libreoffice-style-yaru libreoffice-wiki-publisher libreoffice-writer
#   librevenge-0.0-0 libservlet-api-java libservlet3.1-java
#   libsuitesparseconfig5 libtext-iconv-perl libtommath1 libuno-cppu3
#   libuno-cppuhelpergcc3-3 libuno-purpenvhelpergcc3-3 libuno-sal3
#   libuno-salhelpergcc3-3 libunoloader-java libvisio-0.1-1
#   libwebsocket-api-java libwpd-0.10-10 libwpg-0.3-3 libwps-0.4-4 libxmlsec1
#   libxmlsec1-nss libxtst6 libxxf86dga1 libyajl2 lp-solve openjdk-11-jre
#   poppler-data poppler-utils python3-uno tesseract-ocr-lit uno-libs-private
#   ure ure-java x11-utils
# 0 upgraded, 127 newly installed, 0 to remove and 40 not upgraded.
# Need to get 229 MB of archives.
# After this operation, 859 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 fonts-opensymbol all 2:102.12+LibO7.3.7-0ubuntu0.22.04.10 [103 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-style-colibre all 1:7.3.7-0ubuntu0.22.04.10 [1,294 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libuno-sal3 amd64 1:7.3.7-0ubuntu0.22.04.10 [197 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libuno-salhelpergcc3-3 amd64 1:7.3.7-0ubuntu0.22.04.10 [17.0 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libuno-cppu3 amd64 1:7.3.7-0ubuntu0.22.04.10 [87.8 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 uno-libs-private amd64 1:7.3.7-0ubuntu0.22.04.10 [232 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 liblangtag-common all 0.6.3-2ubuntu1 [193 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/main amd64 liblangtag1 amd64 0.6.3-2ubuntu1 [53.8 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libuno-cppuhelpergcc3-3 amd64 1:7.3.7-0ubuntu0.22.04.10 [343 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libuno-purpenvhelpergcc3-3 amd64 1:7.3.7-0ubuntu0.22.04.10 [15.8 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 ure amd64 1:7.3.7-0ubuntu0.22.04.10 [1,312 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-common all 1:7.3.7-0ubuntu0.22.04.10 [23.4 MB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libabsl20210324 amd64 0~20210324.2-2ubuntu0.2 [386 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/main amd64 libclucene-core1v5 amd64 2.3.3.4+dfsg-1ubuntu5 [530 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy/main amd64 libclucene-contribs1v5 amd64 2.3.3.4+dfsg-1ubuntu5 [96.7 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy/main amd64 libeot0 amd64 0.01-5build2 [28.5 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy/main amd64 libexttextcat-data all 3.4.5-1build2 [179 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy/main amd64 libexttextcat-2.0-0 amd64 3.4.5-1build2 [13.7 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgpgme11 amd64 1.16.0-1.2ubuntu4.2 [136 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgpgmepp6 amd64 1.16.0-1.2ubuntu4.2 [109 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libharfbuzz-icu0 amd64 2.7.4-1ubuntu3.2 [5,890 B]
# Get:22 http://archive.ubuntu.com/ubuntu jammy/main amd64 libhunspell-1.7-0 amd64 1.7.0-4build1 [175 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy/main amd64 libhyphen0 amd64 2.8.8-7build2 [28.2 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy/main amd64 libmythes-1.2-0 amd64 2:1.2.4-4build1 [9,352 B]
# Get:25 http://archive.ubuntu.com/ubuntu jammy/main amd64 liborcus-parser-0.17-0 amd64 0.17.2-2 [107 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy/main amd64 liborcus-0.17-0 amd64 0.17.2-2 [393 kB]
# Get:27 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libyajl2 amd64 2.1.0-3ubuntu0.22.04.1 [21.0 kB]
# Get:28 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libraptor2-0 amd64 2.0.15-0ubuntu4.1 [172 kB]
# Get:29 http://archive.ubuntu.com/ubuntu jammy/main amd64 libmhash2 amd64 0.9.9.9-9build2 [95.9 kB]
# Get:30 http://archive.ubuntu.com/ubuntu jammy/main amd64 librasqal3 amd64 0.9.33-0.2ubuntu1 [193 kB]
# Get:31 http://archive.ubuntu.com/ubuntu jammy/main amd64 librdf0 amd64 1.0.17-1.1ubuntu3 [106 kB]
# Get:32 http://archive.ubuntu.com/ubuntu jammy/main amd64 librevenge-0.0-0 amd64 0.0.4-6ubuntu7 [209 kB]
# Get:33 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxmlsec1 amd64 1.2.33-1build2 [139 kB]
# Get:34 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxmlsec1-nss amd64 1.2.33-1build2 [67.7 kB]
# Get:35 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-core amd64 1:7.3.7-0ubuntu0.22.04.10 [40.5 MB]
# Get:36 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-base-core amd64 1:7.3.7-0ubuntu0.22.04.10 [974 kB]
# Get:37 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libreoffice-base-drivers amd64 1:7.3.7-0ubuntu0.22.04.10 [602 kB]
# Get:38 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libreoffice-base amd64 1:7.3.7-0ubuntu0.22.04.10 [1,725 kB]
# Get:39 http://archive.ubuntu.com/ubuntu jammy/main amd64 poppler-data all 0.4.11-1 [2,171 kB]
# Get:40 http://archive.ubuntu.com/ubuntu jammy/main amd64 libtext-iconv-perl amd64 1.7-7build3 [14.3 kB]
# Get:41 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 apparmor amd64 3.0.4-2ubuntu2.4 [598 kB]
# Get:42 http://archive.ubuntu.com/ubuntu jammy/main amd64 default-jre-headless amd64 2:1.11-72build2 [3,042 B]
# Get:43 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxtst6 amd64 2:1.2.3-1build4 [13.4 kB]
# Get:44 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 openjdk-11-jre amd64 11.0.28+6-1ubuntu1~22.04.1 [214 kB]
# Get:45 http://archive.ubuntu.com/ubuntu jammy/main amd64 default-jre amd64 2:1.11-72build2 [896 B]
# Get:46 http://archive.ubuntu.com/ubuntu jammy/main amd64 dictionaries-common all 1.28.14 [185 kB]
# Get:47 http://archive.ubuntu.com/ubuntu jammy/universe amd64 firebird3.0-common-doc all 3.0.8.33535.ds4-1ubuntu2 [26.8 kB]
# Get:48 http://archive.ubuntu.com/ubuntu jammy/universe amd64 firebird3.0-common all 3.0.8.33535.ds4-1ubuntu2 [15.5 kB]
# Get:49 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libtommath1 amd64 1.2.0-6ubuntu0.22.04.1 [56.5 kB]
# Get:50 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libfbclient2 amd64 3.0.8.33535.ds4-1ubuntu2 [512 kB]
# Get:51 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libib-util amd64 3.0.8.33535.ds4-1ubuntu2 [3,378 B]
# Get:52 http://archive.ubuntu.com/ubuntu jammy/universe amd64 firebird3.0-server-core amd64 3.0.8.33535.ds4-1ubuntu2 [2,533 kB]
# Get:53 http://archive.ubuntu.com/ubuntu jammy/universe amd64 firebird3.0-utils amd64 3.0.8.33535.ds4-1ubuntu2 [872 kB]
# Get:54 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-crosextra-caladea all 20130214-2.1 [82.4 kB]
# Get:55 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-crosextra-carlito all 20130920-1.1 [743 kB]
# Get:56 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-dejavu-core all 2.37-2build1 [1,041 kB]
# Get:57 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-dejavu-extra all 2.37-2build1 [2,041 kB]
# Get:58 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-dejavu all 2.37-2build1 [3,192 B]
# Get:59 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-liberation2 all 2.1.5-1 [1,614 kB]
# Get:60 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-linuxlibertine all 5.3.0-6 [1,627 kB]
# Get:61 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-noto-core all 20201225-1build1 [12.2 MB]
# Get:62 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-noto-extra all 20201225-1build1 [72.4 MB]
# Get:63 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-noto-mono all 20201225-1build1 [397 kB]
# Get:64 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-noto-ui-core all 20201225-1build1 [1,420 kB]
# Get:65 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-sil-gentium all 20081126:1.03-4 [245 kB]
# Get:66 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-sil-gentium-basic all 1.102-1.1 [384 kB]
# Get:67 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgudev-1.0-0 amd64 1:237-2build1 [16.3 kB]
# Get:68 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgstreamer-gl1.0-0 amd64 1.20.1-1ubuntu0.5 [204 kB]
# Get:69 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gstreamer1.0-gl amd64 1.20.1-1ubuntu0.5 [125 kB]
# Get:70 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gstreamer1.0-gtk3 amd64 1.20.3-0ubuntu1.4 [33.3 kB]
# Get:71 http://archive.ubuntu.com/ubuntu jammy/main amd64 hunspell-en-us all 1:2020.12.07-2 [280 kB]
# Get:72 http://archive.ubuntu.com/ubuntu jammy/main amd64 libabw-0.1-1 amd64 0.1.3-1build3 [102 kB]
# Get:73 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxxf86dga1 amd64 2:1.1.5-0ubuntu3 [12.6 kB]
# Get:74 http://archive.ubuntu.com/ubuntu jammy/main amd64 x11-utils amd64 7.7+5build2 [206 kB]
# Get:75 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-wrapper-java all 0.38.0-5build1 [53.1 kB]
# Get:76 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-wrapper-java-jni amd64 0.38.0-5build1 [49.0 kB]
# Get:77 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libbsh-java all 2.0b4-20 [289 kB]
# Get:78 http://archive.ubuntu.com/ubuntu jammy/main amd64 libcdr-0.1-1 amd64 0.1.6-2build2 [392 kB]
# Get:79 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsuitesparseconfig5 amd64 1:5.10.1+dfsg-4build1 [10.4 kB]
# Get:80 http://archive.ubuntu.com/ubuntu jammy/main amd64 libcolamd2 amd64 1:5.10.1+dfsg-4build1 [18.0 kB]
# Get:81 http://archive.ubuntu.com/ubuntu jammy/main amd64 libe-book-0.1-1 amd64 0.1.3-2build2 [148 kB]
# Get:82 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libel-api-java all 3.0.0-3 [64.9 kB]
# Get:83 http://archive.ubuntu.com/ubuntu jammy/main amd64 libepubgen-0.1-1 amd64 0.1.1-1ubuntu5 [120 kB]
# Get:84 http://archive.ubuntu.com/ubuntu jammy/main amd64 libetonyek-0.1-1 amd64 0.1.10-3build1 [637 kB]
# Get:85 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfreehand-0.1-1 amd64 0.1.2-3build2 [272 kB]
# Get:86 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libservlet-api-java all 4.0.1-2 [81.0 kB]
# Get:87 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libjsp-api-java all 2.3.4-3 [53.7 kB]
# Get:88 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libwebsocket-api-java all 1.1-2 [40.1 kB]
# Get:89 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libservlet3.1-java all 1:4.0.1-2 [9,276 B]
# Get:90 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libhsqldb1.8.0-java all 1.8.0.10+dfsg-11 [765 kB]
# Get:91 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libunoloader-java all 1:7.3.7-0ubuntu0.22.04.10 [13.0 kB]
# Get:92 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 ure-java amd64 1:7.3.7-0ubuntu0.22.04.10 [83.5 kB]
# Get:93 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 liblibreoffice-java all 1:7.3.7-0ubuntu0.22.04.10 [1,604 kB]
# Get:94 http://archive.ubuntu.com/ubuntu jammy/main amd64 libmspub-0.1-1 amd64 0.1.4-3build3 [144 kB]
# Get:95 http://archive.ubuntu.com/ubuntu jammy/main amd64 libmwaw-0.3-3 amd64 0.3.21-1build1 [2,375 kB]
# Get:96 http://archive.ubuntu.com/ubuntu jammy/main amd64 libodfgen-0.1-1 amd64 0.1.8-2build2 [245 kB]
# Get:97 http://archive.ubuntu.com/ubuntu jammy/main amd64 libpagemaker-0.0-0 amd64 0.0.4-1build3 [55.9 kB]
# Get:98 http://archive.ubuntu.com/ubuntu jammy/main amd64 lp-solve amd64 5.5.2.5-2build2 [315 kB]
# Get:99 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwps-0.4-4 amd64 0.4.12-2build1 [812 kB]
# Get:100 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-calc amd64 1:7.3.7-0ubuntu0.22.04.10 [8,426 kB]
# Get:101 http://archive.ubuntu.com/ubuntu jammy/main amd64 libvisio-0.1-1 amd64 0.1.7-1build5 [238 kB]
# Get:102 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwpd-0.10-10 amd64 0.10.3-2build1 [209 kB]
# Get:103 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwpg-0.3-3 amd64 0.3.3-1build3 [49.9 kB]
# Get:104 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-draw amd64 1:7.3.7-0ubuntu0.22.04.10 [3,228 kB]
# Get:105 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-impress amd64 1:7.3.7-0ubuntu0.22.04.10 [1,359 kB]
# Get:106 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-math amd64 1:7.3.7-0ubuntu0.22.04.10 [597 kB]
# Get:107 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libreoffice-report-builder-bin amd64 1:7.3.7-0ubuntu0.22.04.10 [971 kB]
# Get:108 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-writer amd64 1:7.3.7-0ubuntu0.22.04.10 [10.3 MB]
# Get:109 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 python3-uno amd64 1:7.3.7-0ubuntu0.22.04.10 [148 kB]
# Get:110 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libreoffice amd64 1:7.3.7-0ubuntu0.22.04.10 [12.9 kB]
# Get:111 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-gnome amd64 1:7.3.7-0ubuntu0.22.04.10 [72.9 kB]
# Get:112 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-gtk3 amd64 1:7.3.7-0ubuntu0.22.04.10 [509 kB]
# Get:113 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-java-common all 1:7.3.7-0ubuntu0.22.04.10 [621 kB]
# Get:114 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libreoffice-report-builder all 1:7.3.7-0ubuntu0.22.04.10 [2,112 kB]
# Get:115 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libreoffice-script-provider-bsh all 1:7.3.7-0ubuntu0.22.04.10 [42.3 kB]
# Get:116 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libreoffice-script-provider-js all 1:7.3.7-0ubuntu0.22.04.10 [645 kB]
# Get:117 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libreoffice-script-provider-python all 1:7.3.7-0ubuntu0.22.04.10 [16.5 kB]
# Get:118 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libreoffice-sdbc-firebird amd64 1:7.3.7-0ubuntu0.22.04.10 [176 kB]
# Get:119 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libreoffice-sdbc-hsqldb amd64 1:7.3.7-0ubuntu0.22.04.10 [135 kB]
# Get:120 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libreoffice-sdbc-mysql amd64 1:7.3.7-0ubuntu0.22.04.10 [123 kB]
# Get:121 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libreoffice-sdbc-postgresql amd64 1:7.3.7-0ubuntu0.22.04.10 [279 kB]
# Get:122 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-style-elementary all 1:7.3.7-0ubuntu0.22.04.10 [8,020 kB]
# Get:123 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-style-yaru all 1:7.3.7-0ubuntu0.22.04.10 [3,761 kB]
# Get:124 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libreoffice-wiki-publisher all 1.2.0+LibO7.3.7-0ubuntu0.22.04.10 [7,930 B]
# Get:125 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 poppler-utils amd64 22.02.0-2ubuntu0.11 [186 kB]
# Get:126 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-lit all 1:4.00~git30-7274cfa-1.1 [1,140 kB]
# Get:127 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-nlpsolver all 0.9+LibO7.3.7-0ubuntu0.22.04.10 [7,986 B]
# Fetched 229 MB in 7s (30.9 MB/s)
# Extracting templates from packages: 100%
# Preconfiguring packages ...
# Selecting previously unselected package fonts-opensymbol.
# (Reading database ... 126675 files and directories currently installed.)
# Preparing to unpack .../000-fonts-opensymbol_2%3a102.12+LibO7.3.7-0ubuntu0.22.04.10_all.deb ...
# Unpacking fonts-opensymbol (2:102.12+LibO7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libreoffice-style-colibre.
# Preparing to unpack .../001-libreoffice-style-colibre_1%3a7.3.7-0ubuntu0.22.04.10_all.deb ...
# Unpacking libreoffice-style-colibre (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libuno-sal3.
# Preparing to unpack .../002-libuno-sal3_1%3a7.3.7-0ubuntu0.22.04.10_amd64.deb ...
# Unpacking libuno-sal3 (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libuno-salhelpergcc3-3.
# Preparing to unpack .../003-libuno-salhelpergcc3-3_1%3a7.3.7-0ubuntu0.22.04.10_amd64.deb ...
# Unpacking libuno-salhelpergcc3-3 (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libuno-cppu3.
# Preparing to unpack .../004-libuno-cppu3_1%3a7.3.7-0ubuntu0.22.04.10_amd64.deb ...
# Unpacking libuno-cppu3 (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package uno-libs-private.
# Preparing to unpack .../005-uno-libs-private_1%3a7.3.7-0ubuntu0.22.04.10_amd64.deb ...
# Unpacking uno-libs-private (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package liblangtag-common.
# Preparing to unpack .../006-liblangtag-common_0.6.3-2ubuntu1_all.deb ...
# Unpacking liblangtag-common (0.6.3-2ubuntu1) ...
# Selecting previously unselected package liblangtag1:amd64.
# Preparing to unpack .../007-liblangtag1_0.6.3-2ubuntu1_amd64.deb ...
# Unpacking liblangtag1:amd64 (0.6.3-2ubuntu1) ...
# Selecting previously unselected package libuno-cppuhelpergcc3-3.
# Preparing to unpack .../008-libuno-cppuhelpergcc3-3_1%3a7.3.7-0ubuntu0.22.04.10_amd64.deb ...
# Unpacking libuno-cppuhelpergcc3-3 (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libuno-purpenvhelpergcc3-3.
# Preparing to unpack .../009-libuno-purpenvhelpergcc3-3_1%3a7.3.7-0ubuntu0.22.04.10_amd64.deb ...
# Unpacking libuno-purpenvhelpergcc3-3 (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package ure.
# Preparing to unpack .../010-ure_1%3a7.3.7-0ubuntu0.22.04.10_amd64.deb ...
# Unpacking ure (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libreoffice-common.
# Preparing to unpack .../011-libreoffice-common_1%3a7.3.7-0ubuntu0.22.04.10_all.deb ...
# Unpacking libreoffice-common (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libabsl20210324:amd64.
# Preparing to unpack .../012-libabsl20210324_0~20210324.2-2ubuntu0.2_amd64.deb ...
# Unpacking libabsl20210324:amd64 (0~20210324.2-2ubuntu0.2) ...
# Selecting previously unselected package libclucene-core1v5:amd64.
# Preparing to unpack .../013-libclucene-core1v5_2.3.3.4+dfsg-1ubuntu5_amd64.deb ...
# Unpacking libclucene-core1v5:amd64 (2.3.3.4+dfsg-1ubuntu5) ...
# Selecting previously unselected package libclucene-contribs1v5:amd64.
# Preparing to unpack .../014-libclucene-contribs1v5_2.3.3.4+dfsg-1ubuntu5_amd64.deb ...
# Unpacking libclucene-contribs1v5:amd64 (2.3.3.4+dfsg-1ubuntu5) ...
# Selecting previously unselected package libeot0:amd64.
# Preparing to unpack .../015-libeot0_0.01-5build2_amd64.deb ...
# Unpacking libeot0:amd64 (0.01-5build2) ...
# Selecting previously unselected package libexttextcat-data.
# Preparing to unpack .../016-libexttextcat-data_3.4.5-1build2_all.deb ...
# Unpacking libexttextcat-data (3.4.5-1build2) ...
# Selecting previously unselected package libexttextcat-2.0-0:amd64.
# Preparing to unpack .../017-libexttextcat-2.0-0_3.4.5-1build2_amd64.deb ...
# Unpacking libexttextcat-2.0-0:amd64 (3.4.5-1build2) ...
# Selecting previously unselected package libgpgme11:amd64.
# Preparing to unpack .../018-libgpgme11_1.16.0-1.2ubuntu4.2_amd64.deb ...
# Unpacking libgpgme11:amd64 (1.16.0-1.2ubuntu4.2) ...
# Selecting previously unselected package libgpgmepp6:amd64.
# Preparing to unpack .../019-libgpgmepp6_1.16.0-1.2ubuntu4.2_amd64.deb ...
# Unpacking libgpgmepp6:amd64 (1.16.0-1.2ubuntu4.2) ...
# Selecting previously unselected package libharfbuzz-icu0:amd64.
# Preparing to unpack .../020-libharfbuzz-icu0_2.7.4-1ubuntu3.2_amd64.deb ...
# Unpacking libharfbuzz-icu0:amd64 (2.7.4-1ubuntu3.2) ...
# Selecting previously unselected package libhunspell-1.7-0:amd64.
# Preparing to unpack .../021-libhunspell-1.7-0_1.7.0-4build1_amd64.deb ...
# Unpacking libhunspell-1.7-0:amd64 (1.7.0-4build1) ...
# Selecting previously unselected package libhyphen0:amd64.
# Preparing to unpack .../022-libhyphen0_2.8.8-7build2_amd64.deb ...
# Unpacking libhyphen0:amd64 (2.8.8-7build2) ...
# Selecting previously unselected package libmythes-1.2-0:amd64.
# Preparing to unpack .../023-libmythes-1.2-0_2%3a1.2.4-4build1_amd64.deb ...
# Unpacking libmythes-1.2-0:amd64 (2:1.2.4-4build1) ...
# Selecting previously unselected package liborcus-parser-0.17-0:amd64.
# Preparing to unpack .../024-liborcus-parser-0.17-0_0.17.2-2_amd64.deb ...
# Unpacking liborcus-parser-0.17-0:amd64 (0.17.2-2) ...
# Selecting previously unselected package liborcus-0.17-0:amd64.
# Preparing to unpack .../025-liborcus-0.17-0_0.17.2-2_amd64.deb ...
# Unpacking liborcus-0.17-0:amd64 (0.17.2-2) ...
# Selecting previously unselected package libyajl2:amd64.
# Preparing to unpack .../026-libyajl2_2.1.0-3ubuntu0.22.04.1_amd64.deb ...
# Unpacking libyajl2:amd64 (2.1.0-3ubuntu0.22.04.1) ...
# Selecting previously unselected package libraptor2-0:amd64.
# Preparing to unpack .../027-libraptor2-0_2.0.15-0ubuntu4.1_amd64.deb ...
# Unpacking libraptor2-0:amd64 (2.0.15-0ubuntu4.1) ...
# Selecting previously unselected package libmhash2:amd64.
# Preparing to unpack .../028-libmhash2_0.9.9.9-9build2_amd64.deb ...
# Unpacking libmhash2:amd64 (0.9.9.9-9build2) ...
# Selecting previously unselected package librasqal3:amd64.
# Preparing to unpack .../029-librasqal3_0.9.33-0.2ubuntu1_amd64.deb ...
# Unpacking librasqal3:amd64 (0.9.33-0.2ubuntu1) ...
# Selecting previously unselected package librdf0:amd64.
# Preparing to unpack .../030-librdf0_1.0.17-1.1ubuntu3_amd64.deb ...
# Unpacking librdf0:amd64 (1.0.17-1.1ubuntu3) ...
# Selecting previously unselected package librevenge-0.0-0:amd64.
# Preparing to unpack .../031-librevenge-0.0-0_0.0.4-6ubuntu7_amd64.deb ...
# Unpacking librevenge-0.0-0:amd64 (0.0.4-6ubuntu7) ...
# Selecting previously unselected package libxmlsec1:amd64.
# Preparing to unpack .../032-libxmlsec1_1.2.33-1build2_amd64.deb ...
# Unpacking libxmlsec1:amd64 (1.2.33-1build2) ...
# Selecting previously unselected package libxmlsec1-nss:amd64.
# Preparing to unpack .../033-libxmlsec1-nss_1.2.33-1build2_amd64.deb ...
# Unpacking libxmlsec1-nss:amd64 (1.2.33-1build2) ...
# Selecting previously unselected package libreoffice-core.
# Preparing to unpack .../034-libreoffice-core_1%3a7.3.7-0ubuntu0.22.04.10_amd64.deb ...
# Unpacking libreoffice-core (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libreoffice-base-core.
# Preparing to unpack .../035-libreoffice-base-core_1%3a7.3.7-0ubuntu0.22.04.10_amd64.deb ...
# Unpacking libreoffice-base-core (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libreoffice-base-drivers.
# Preparing to unpack .../036-libreoffice-base-drivers_1%3a7.3.7-0ubuntu0.22.04.10_amd64.deb ...
# Unpacking libreoffice-base-drivers (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libreoffice-base.
# Preparing to unpack .../037-libreoffice-base_1%3a7.3.7-0ubuntu0.22.04.10_amd64.deb ...
# No diversion 'diversion of /usr/lib/libreoffice/share/basic/dialog.xlc to /usr/lib/libreoffice/share/basic/dialog.xlc.noaccess by libreoffice-base', none removed.
# No diversion 'diversion of /usr/lib/libreoffice/share/basic/script.xlc to /usr/lib/libreoffice/share/basic/script.xlc.noaccess by libreoffice-base', none removed.
# Unpacking libreoffice-base (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package poppler-data.
# Preparing to unpack .../038-poppler-data_0.4.11-1_all.deb ...
# Unpacking poppler-data (0.4.11-1) ...
# Selecting previously unselected package libtext-iconv-perl.
# Preparing to unpack .../039-libtext-iconv-perl_1.7-7build3_amd64.deb ...
# Unpacking libtext-iconv-perl (1.7-7build3) ...
# Selecting previously unselected package apparmor.
# Preparing to unpack .../040-apparmor_3.0.4-2ubuntu2.4_amd64.deb ...
# Unpacking apparmor (3.0.4-2ubuntu2.4) ...
# Selecting previously unselected package default-jre-headless.
# Preparing to unpack .../041-default-jre-headless_2%3a1.11-72build2_amd64.deb ...
# Unpacking default-jre-headless (2:1.11-72build2) ...
# Selecting previously unselected package libxtst6:amd64.
# Preparing to unpack .../042-libxtst6_2%3a1.2.3-1build4_amd64.deb ...
# Unpacking libxtst6:amd64 (2:1.2.3-1build4) ...
# Selecting previously unselected package openjdk-11-jre:amd64.
# Preparing to unpack .../043-openjdk-11-jre_11.0.28+6-1ubuntu1~22.04.1_amd64.deb ...
# Unpacking openjdk-11-jre:amd64 (11.0.28+6-1ubuntu1~22.04.1) ...
# Selecting previously unselected package default-jre.
# Preparing to unpack .../044-default-jre_2%3a1.11-72build2_amd64.deb ...
# Unpacking default-jre (2:1.11-72build2) ...
# Selecting previously unselected package dictionaries-common.
# Preparing to unpack .../045-dictionaries-common_1.28.14_all.deb ...
# Adding 'diversion of /usr/share/dict/words to /usr/share/dict/words.pre-dictionaries-common by dictionaries-common'
# Unpacking dictionaries-common (1.28.14) ...
# Selecting previously unselected package firebird3.0-common-doc.
# Preparing to unpack .../046-firebird3.0-common-doc_3.0.8.33535.ds4-1ubuntu2_all.deb ...
# Unpacking firebird3.0-common-doc (3.0.8.33535.ds4-1ubuntu2) ...
# Selecting previously unselected package firebird3.0-common.
# Preparing to unpack .../047-firebird3.0-common_3.0.8.33535.ds4-1ubuntu2_all.deb ...
# Unpacking firebird3.0-common (3.0.8.33535.ds4-1ubuntu2) ...
# Selecting previously unselected package libtommath1:amd64.
# Preparing to unpack .../048-libtommath1_1.2.0-6ubuntu0.22.04.1_amd64.deb ...
# Unpacking libtommath1:amd64 (1.2.0-6ubuntu0.22.04.1) ...
# Selecting previously unselected package libfbclient2:amd64.
# Preparing to unpack .../049-libfbclient2_3.0.8.33535.ds4-1ubuntu2_amd64.deb ...
# Unpacking libfbclient2:amd64 (3.0.8.33535.ds4-1ubuntu2) ...
# Selecting previously unselected package libib-util:amd64.
# Preparing to unpack .../050-libib-util_3.0.8.33535.ds4-1ubuntu2_amd64.deb ...
# Unpacking libib-util:amd64 (3.0.8.33535.ds4-1ubuntu2) ...
# Selecting previously unselected package firebird3.0-server-core:amd64.
# Preparing to unpack .../051-firebird3.0-server-core_3.0.8.33535.ds4-1ubuntu2_amd64.deb ...
# Unpacking firebird3.0-server-core:amd64 (3.0.8.33535.ds4-1ubuntu2) ...
# Selecting previously unselected package firebird3.0-utils.
# Preparing to unpack .../052-firebird3.0-utils_3.0.8.33535.ds4-1ubuntu2_amd64.deb ...
# Unpacking firebird3.0-utils (3.0.8.33535.ds4-1ubuntu2) ...
# Selecting previously unselected package fonts-crosextra-caladea.
# Preparing to unpack .../053-fonts-crosextra-caladea_20130214-2.1_all.deb ...
# Unpacking fonts-crosextra-caladea (20130214-2.1) ...
# Selecting previously unselected package fonts-crosextra-carlito.
# Preparing to unpack .../054-fonts-crosextra-carlito_20130920-1.1_all.deb ...
# Unpacking fonts-crosextra-carlito (20130920-1.1) ...
# Selecting previously unselected package fonts-dejavu-core.
# Preparing to unpack .../055-fonts-dejavu-core_2.37-2build1_all.deb ...
# Unpacking fonts-dejavu-core (2.37-2build1) ...
# Selecting previously unselected package fonts-dejavu-extra.
# Preparing to unpack .../056-fonts-dejavu-extra_2.37-2build1_all.deb ...
# Unpacking fonts-dejavu-extra (2.37-2build1) ...
# Selecting previously unselected package fonts-dejavu.
# Preparing to unpack .../057-fonts-dejavu_2.37-2build1_all.deb ...
# Unpacking fonts-dejavu (2.37-2build1) ...
# Selecting previously unselected package fonts-liberation2.
# Preparing to unpack .../058-fonts-liberation2_2.1.5-1_all.deb ...
# Unpacking fonts-liberation2 (2.1.5-1) ...
# Selecting previously unselected package fonts-linuxlibertine.
# Preparing to unpack .../059-fonts-linuxlibertine_5.3.0-6_all.deb ...
# Unpacking fonts-linuxlibertine (5.3.0-6) ...
# Selecting previously unselected package fonts-noto-core.
# Preparing to unpack .../060-fonts-noto-core_20201225-1build1_all.deb ...
# Unpacking fonts-noto-core (20201225-1build1) ...
# Selecting previously unselected package fonts-noto-extra.
# Preparing to unpack .../061-fonts-noto-extra_20201225-1build1_all.deb ...
# Unpacking fonts-noto-extra (20201225-1build1) ...
# Selecting previously unselected package fonts-noto-mono.
# Preparing to unpack .../062-fonts-noto-mono_20201225-1build1_all.deb ...
# Unpacking fonts-noto-mono (20201225-1build1) ...
# Selecting previously unselected package fonts-noto-ui-core.
# Preparing to unpack .../063-fonts-noto-ui-core_20201225-1build1_all.deb ...
# Unpacking fonts-noto-ui-core (20201225-1build1) ...
# Selecting previously unselected package fonts-sil-gentium.
# Preparing to unpack .../064-fonts-sil-gentium_20081126%3a1.03-4_all.deb ...
# Unpacking fonts-sil-gentium (20081126:1.03-4) ...
# Selecting previously unselected package fonts-sil-gentium-basic.
# Preparing to unpack .../065-fonts-sil-gentium-basic_1.102-1.1_all.deb ...
# Unpacking fonts-sil-gentium-basic (1.102-1.1) ...
# Selecting previously unselected package libgudev-1.0-0:amd64.
# Preparing to unpack .../066-libgudev-1.0-0_1%3a237-2build1_amd64.deb ...
# Unpacking libgudev-1.0-0:amd64 (1:237-2build1) ...
# Selecting previously unselected package libgstreamer-gl1.0-0:amd64.
# Preparing to unpack .../067-libgstreamer-gl1.0-0_1.20.1-1ubuntu0.5_amd64.deb ...
# Unpacking libgstreamer-gl1.0-0:amd64 (1.20.1-1ubuntu0.5) ...
# Selecting previously unselected package gstreamer1.0-gl:amd64.
# Preparing to unpack .../068-gstreamer1.0-gl_1.20.1-1ubuntu0.5_amd64.deb ...
# Unpacking gstreamer1.0-gl:amd64 (1.20.1-1ubuntu0.5) ...
# Selecting previously unselected package gstreamer1.0-gtk3:amd64.
# Preparing to unpack .../069-gstreamer1.0-gtk3_1.20.3-0ubuntu1.4_amd64.deb ...
# Unpacking gstreamer1.0-gtk3:amd64 (1.20.3-0ubuntu1.4) ...
# Selecting previously unselected package hunspell-en-us.
# Preparing to unpack .../070-hunspell-en-us_1%3a2020.12.07-2_all.deb ...
# Unpacking hunspell-en-us (1:2020.12.07-2) ...
# Selecting previously unselected package libabw-0.1-1:amd64.
# Preparing to unpack .../071-libabw-0.1-1_0.1.3-1build3_amd64.deb ...
# Unpacking libabw-0.1-1:amd64 (0.1.3-1build3) ...
# Selecting previously unselected package libxxf86dga1:amd64.
# Preparing to unpack .../072-libxxf86dga1_2%3a1.1.5-0ubuntu3_amd64.deb ...
# Unpacking libxxf86dga1:amd64 (2:1.1.5-0ubuntu3) ...
# Selecting previously unselected package x11-utils.
# Preparing to unpack .../073-x11-utils_7.7+5build2_amd64.deb ...
# Unpacking x11-utils (7.7+5build2) ...
# Selecting previously unselected package libatk-wrapper-java.
# Preparing to unpack .../074-libatk-wrapper-java_0.38.0-5build1_all.deb ...
# Unpacking libatk-wrapper-java (0.38.0-5build1) ...
# Selecting previously unselected package libatk-wrapper-java-jni:amd64.
# Preparing to unpack .../075-libatk-wrapper-java-jni_0.38.0-5build1_amd64.deb ...
# Unpacking libatk-wrapper-java-jni:amd64 (0.38.0-5build1) ...
# Selecting previously unselected package libbsh-java.
# Preparing to unpack .../076-libbsh-java_2.0b4-20_all.deb ...
# Unpacking libbsh-java (2.0b4-20) ...
# Selecting previously unselected package libcdr-0.1-1:amd64.
# Preparing to unpack .../077-libcdr-0.1-1_0.1.6-2build2_amd64.deb ...
# Unpacking libcdr-0.1-1:amd64 (0.1.6-2build2) ...
# Selecting previously unselected package libsuitesparseconfig5:amd64.
# Preparing to unpack .../078-libsuitesparseconfig5_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libsuitesparseconfig5:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package libcolamd2:amd64.
# Preparing to unpack .../079-libcolamd2_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libcolamd2:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package libe-book-0.1-1:amd64.
# Preparing to unpack .../080-libe-book-0.1-1_0.1.3-2build2_amd64.deb ...
# Unpacking libe-book-0.1-1:amd64 (0.1.3-2build2) ...
# Selecting previously unselected package libel-api-java.
# Preparing to unpack .../081-libel-api-java_3.0.0-3_all.deb ...
# Unpacking libel-api-java (3.0.0-3) ...
# Selecting previously unselected package libepubgen-0.1-1:amd64.
# Preparing to unpack .../082-libepubgen-0.1-1_0.1.1-1ubuntu5_amd64.deb ...
# Unpacking libepubgen-0.1-1:amd64 (0.1.1-1ubuntu5) ...
# Selecting previously unselected package libetonyek-0.1-1:amd64.
# Preparing to unpack .../083-libetonyek-0.1-1_0.1.10-3build1_amd64.deb ...
# Unpacking libetonyek-0.1-1:amd64 (0.1.10-3build1) ...
# Selecting previously unselected package libfreehand-0.1-1.
# Preparing to unpack .../084-libfreehand-0.1-1_0.1.2-3build2_amd64.deb ...
# Unpacking libfreehand-0.1-1 (0.1.2-3build2) ...
# Selecting previously unselected package libservlet-api-java.
# Preparing to unpack .../085-libservlet-api-java_4.0.1-2_all.deb ...
# Unpacking libservlet-api-java (4.0.1-2) ...
# Selecting previously unselected package libjsp-api-java.
# Preparing to unpack .../086-libjsp-api-java_2.3.4-3_all.deb ...
# Unpacking libjsp-api-java (2.3.4-3) ...
# Selecting previously unselected package libwebsocket-api-java.
# Preparing to unpack .../087-libwebsocket-api-java_1.1-2_all.deb ...
# Unpacking libwebsocket-api-java (1.1-2) ...
# Selecting previously unselected package libservlet3.1-java.
# Preparing to unpack .../088-libservlet3.1-java_1%3a4.0.1-2_all.deb ...
# Unpacking libservlet3.1-java (1:4.0.1-2) ...
# Selecting previously unselected package libhsqldb1.8.0-java.
# Preparing to unpack .../089-libhsqldb1.8.0-java_1.8.0.10+dfsg-11_all.deb ...
# Unpacking libhsqldb1.8.0-java (1.8.0.10+dfsg-11) ...
# Selecting previously unselected package libunoloader-java.
# Preparing to unpack .../090-libunoloader-java_1%3a7.3.7-0ubuntu0.22.04.10_all.deb ...
# Unpacking libunoloader-java (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package ure-java.
# Preparing to unpack .../091-ure-java_1%3a7.3.7-0ubuntu0.22.04.10_amd64.deb ...
# Unpacking ure-java (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package liblibreoffice-java.
# Preparing to unpack .../092-liblibreoffice-java_1%3a7.3.7-0ubuntu0.22.04.10_all.deb ...
# Unpacking liblibreoffice-java (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libmspub-0.1-1:amd64.
# Preparing to unpack .../093-libmspub-0.1-1_0.1.4-3build3_amd64.deb ...
# Unpacking libmspub-0.1-1:amd64 (0.1.4-3build3) ...
# Selecting previously unselected package libmwaw-0.3-3:amd64.
# Preparing to unpack .../094-libmwaw-0.3-3_0.3.21-1build1_amd64.deb ...
# Unpacking libmwaw-0.3-3:amd64 (0.3.21-1build1) ...
# Selecting previously unselected package libodfgen-0.1-1:amd64.
# Preparing to unpack .../095-libodfgen-0.1-1_0.1.8-2build2_amd64.deb ...
# Unpacking libodfgen-0.1-1:amd64 (0.1.8-2build2) ...
# Selecting previously unselected package libpagemaker-0.0-0:amd64.
# Preparing to unpack .../096-libpagemaker-0.0-0_0.0.4-1build3_amd64.deb ...
# Unpacking libpagemaker-0.0-0:amd64 (0.0.4-1build3) ...
# Selecting previously unselected package lp-solve.
# Preparing to unpack .../097-lp-solve_5.5.2.5-2build2_amd64.deb ...
# Unpacking lp-solve (5.5.2.5-2build2) ...
# Selecting previously unselected package libwps-0.4-4:amd64.
# Preparing to unpack .../098-libwps-0.4-4_0.4.12-2build1_amd64.deb ...
# Unpacking libwps-0.4-4:amd64 (0.4.12-2build1) ...
# Selecting previously unselected package libreoffice-calc.
# Preparing to unpack .../099-libreoffice-calc_1%3a7.3.7-0ubuntu0.22.04.10_amd64.deb ...
# Unpacking libreoffice-calc (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libvisio-0.1-1:amd64.
# Preparing to unpack .../100-libvisio-0.1-1_0.1.7-1build5_amd64.deb ...
# Unpacking libvisio-0.1-1:amd64 (0.1.7-1build5) ...
# Selecting previously unselected package libwpd-0.10-10:amd64.
# Preparing to unpack .../101-libwpd-0.10-10_0.10.3-2build1_amd64.deb ...
# Unpacking libwpd-0.10-10:amd64 (0.10.3-2build1) ...
# Selecting previously unselected package libwpg-0.3-3:amd64.
# Preparing to unpack .../102-libwpg-0.3-3_0.3.3-1build3_amd64.deb ...
# Unpacking libwpg-0.3-3:amd64 (0.3.3-1build3) ...
# Selecting previously unselected package libreoffice-draw.
# Preparing to unpack .../103-libreoffice-draw_1%3a7.3.7-0ubuntu0.22.04.10_amd64.deb ...
# Unpacking libreoffice-draw (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libreoffice-impress.
# Preparing to unpack .../104-libreoffice-impress_1%3a7.3.7-0ubuntu0.22.04.10_amd64.deb ...
# Unpacking libreoffice-impress (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libreoffice-math.
# Preparing to unpack .../105-libreoffice-math_1%3a7.3.7-0ubuntu0.22.04.10_amd64.deb ...
# Unpacking libreoffice-math (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libreoffice-report-builder-bin.
# Preparing to unpack .../106-libreoffice-report-builder-bin_1%3a7.3.7-0ubuntu0.22.04.10_amd64.deb ...
# Unpacking libreoffice-report-builder-bin (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libreoffice-writer.
# Preparing to unpack .../107-libreoffice-writer_1%3a7.3.7-0ubuntu0.22.04.10_amd64.deb ...
# Unpacking libreoffice-writer (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package python3-uno.
# Preparing to unpack .../108-python3-uno_1%3a7.3.7-0ubuntu0.22.04.10_amd64.deb ...
# Unpacking python3-uno (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libreoffice.
# Preparing to unpack .../109-libreoffice_1%3a7.3.7-0ubuntu0.22.04.10_amd64.deb ...
# Unpacking libreoffice (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libreoffice-gnome.
# Preparing to unpack .../110-libreoffice-gnome_1%3a7.3.7-0ubuntu0.22.04.10_amd64.deb ...
# Unpacking libreoffice-gnome (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libreoffice-gtk3.
# Preparing to unpack .../111-libreoffice-gtk3_1%3a7.3.7-0ubuntu0.22.04.10_amd64.deb ...
# Unpacking libreoffice-gtk3 (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libreoffice-java-common.
# Preparing to unpack .../112-libreoffice-java-common_1%3a7.3.7-0ubuntu0.22.04.10_all.deb ...
# Unpacking libreoffice-java-common (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libreoffice-report-builder.
# Preparing to unpack .../113-libreoffice-report-builder_1%3a7.3.7-0ubuntu0.22.04.10_all.deb ...
# Unpacking libreoffice-report-builder (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libreoffice-script-provider-bsh.
# Preparing to unpack .../114-libreoffice-script-provider-bsh_1%3a7.3.7-0ubuntu0.22.04.10_all.deb ...
# Unpacking libreoffice-script-provider-bsh (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libreoffice-script-provider-js.
# Preparing to unpack .../115-libreoffice-script-provider-js_1%3a7.3.7-0ubuntu0.22.04.10_all.deb ...
# Unpacking libreoffice-script-provider-js (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libreoffice-script-provider-python.
# Preparing to unpack .../116-libreoffice-script-provider-python_1%3a7.3.7-0ubuntu0.22.04.10_all.deb ...
# Unpacking libreoffice-script-provider-python (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libreoffice-sdbc-firebird.
# Preparing to unpack .../117-libreoffice-sdbc-firebird_1%3a7.3.7-0ubuntu0.22.04.10_amd64.deb ...
# Unpacking libreoffice-sdbc-firebird (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libreoffice-sdbc-hsqldb.
# Preparing to unpack .../118-libreoffice-sdbc-hsqldb_1%3a7.3.7-0ubuntu0.22.04.10_amd64.deb ...
# Unpacking libreoffice-sdbc-hsqldb (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libreoffice-sdbc-mysql.
# Preparing to unpack .../119-libreoffice-sdbc-mysql_1%3a7.3.7-0ubuntu0.22.04.10_amd64.deb ...
# Unpacking libreoffice-sdbc-mysql (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libreoffice-sdbc-postgresql.
# Preparing to unpack .../120-libreoffice-sdbc-postgresql_1%3a7.3.7-0ubuntu0.22.04.10_amd64.deb ...
# Unpacking libreoffice-sdbc-postgresql (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libreoffice-style-elementary.
# Preparing to unpack .../121-libreoffice-style-elementary_1%3a7.3.7-0ubuntu0.22.04.10_all.deb ...
# Unpacking libreoffice-style-elementary (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libreoffice-style-yaru.
# Preparing to unpack .../122-libreoffice-style-yaru_1%3a7.3.7-0ubuntu0.22.04.10_all.deb ...
# Unpacking libreoffice-style-yaru (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libreoffice-wiki-publisher.
# Preparing to unpack .../123-libreoffice-wiki-publisher_1.2.0+LibO7.3.7-0ubuntu0.22.04.10_all.deb ...
# Unpacking libreoffice-wiki-publisher (1.2.0+LibO7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package poppler-utils.
# Preparing to unpack .../124-poppler-utils_22.02.0-2ubuntu0.11_amd64.deb ...
# Unpacking poppler-utils (22.02.0-2ubuntu0.11) ...
# Selecting previously unselected package tesseract-ocr-lit.
# Preparing to unpack .../125-tesseract-ocr-lit_1%3a4.00~git30-7274cfa-1.1_all.deb ...
# Unpacking tesseract-ocr-lit (1:4.00~git30-7274cfa-1.1) ...
# Selecting previously unselected package libreoffice-nlpsolver.
# Preparing to unpack .../126-libreoffice-nlpsolver_0.9+LibO7.3.7-0ubuntu0.22.04.10_all.deb ...
# Unpacking libreoffice-nlpsolver (0.9+LibO7.3.7-0ubuntu0.22.04.10) ...
# Setting up libtext-iconv-perl (1.7-7build3) ...
# Setting up fonts-sil-gentium-basic (1.102-1.1) ...
# Setting up libharfbuzz-icu0:amd64 (2.7.4-1ubuntu3.2) ...
# Setting up fonts-noto-mono (20201225-1build1) ...
# Setting up default-jre-headless (2:1.11-72build2) ...
# Setting up libhyphen0:amd64 (2.8.8-7build2) ...
# Setting up tesseract-ocr-lit (1:4.00~git30-7274cfa-1.1) ...
# Setting up dictionaries-common (1.28.14) ...
# Setting up libtommath1:amd64 (1.2.0-6ubuntu0.22.04.1) ...
# Setting up fonts-noto-extra (20201225-1build1) ...
# Setting up libxtst6:amd64 (2:1.2.3-1build4) ...
# Setting up libyajl2:amd64 (2.1.0-3ubuntu0.22.04.1) ...
# Setting up libuno-sal3 (1:7.3.7-0ubuntu0.22.04.10) ...
# Setting up libxxf86dga1:amd64 (2:1.1.5-0ubuntu3) ...
# Setting up libel-api-java (3.0.0-3) ...
# Setting up openjdk-11-jre:amd64 (11.0.28+6-1ubuntu1~22.04.1) ...
# Setting up libeot0:amd64 (0.01-5build2) ...
# Setting up default-jre (2:1.11-72build2) ...
# Setting up libgpgme11:amd64 (1.16.0-1.2ubuntu4.2) ...
# Setting up firebird3.0-common-doc (3.0.8.33535.ds4-1ubuntu2) ...
# Setting up librevenge-0.0-0:amd64 (0.0.4-6ubuntu7) ...
# Setting up poppler-data (0.4.11-1) ...
# Setting up fonts-crosextra-carlito (20130920-1.1) ...
# Setting up firebird3.0-common (3.0.8.33535.ds4-1ubuntu2) ...
# Setting up apparmor (3.0.4-2ubuntu2.4) ...
# Created symlink /etc/systemd/system/sysinit.target.wants/apparmor.service → /lib/systemd/system/apparmor.service.
# Setting up fonts-sil-gentium (20081126:1.03-4) ...
# Setting up libreoffice-style-colibre (1:7.3.7-0ubuntu0.22.04.10) ...
# Setting up liborcus-parser-0.17-0:amd64 (0.17.2-2) ...
# Setting up fonts-liberation2 (2.1.5-1) ...
# Setting up libwebsocket-api-java (1.1-2) ...
# Setting up fonts-dejavu-core (2.37-2build1) ...
# Setting up libfreehand-0.1-1 (0.1.2-3build2) ...
# Setting up libclucene-core1v5:amd64 (2.3.3.4+dfsg-1ubuntu5) ...
# Setting up libabsl20210324:amd64 (0~20210324.2-2ubuntu0.2) ...
# Setting up fonts-linuxlibertine (5.3.0-6) ...
# Setting up libbsh-java (2.0b4-20) ...
# Setting up libjsp-api-java (2.3.4-3) ...
# Setting up libmhash2:amd64 (0.9.9.9-9build2) ...
# Setting up libmythes-1.2-0:amd64 (2:1.2.4-4build1) ...
# Setting up fonts-dejavu-extra (2.37-2build1) ...
# Setting up libexttextcat-data (3.4.5-1build2) ...
# Setting up libabw-0.1-1:amd64 (0.1.3-1build3) ...
# Setting up libservlet-api-java (4.0.1-2) ...
# Setting up libepubgen-0.1-1:amd64 (0.1.1-1ubuntu5) ...
# Setting up x11-utils (7.7+5build2) ...
# Setting up hunspell-en-us (1:2020.12.07-2) ...
# Setting up libuno-salhelpergcc3-3 (1:7.3.7-0ubuntu0.22.04.10) ...
# Setting up fonts-crosextra-caladea (20130214-2.1) ...
# Setting up libreoffice-style-yaru (1:7.3.7-0ubuntu0.22.04.10) ...
# Setting up poppler-utils (22.02.0-2ubuntu0.11) ...
# Setting up libatk-wrapper-java (0.38.0-5build1) ...
# Setting up liblangtag-common (0.6.3-2ubuntu1) ...
# Setting up libib-util:amd64 (3.0.8.33535.ds4-1ubuntu2) ...
# Setting up libhunspell-1.7-0:amd64 (1.7.0-4build1) ...
# Setting up libunoloader-java (1:7.3.7-0ubuntu0.22.04.10) ...
# Setting up fonts-noto-ui-core (20201225-1build1) ...
# Setting up libxmlsec1:amd64 (1.2.33-1build2) ...
# Setting up libwpd-0.10-10:amd64 (0.10.3-2build1) ...
# Setting up fonts-noto-core (20201225-1build1) ...
# Setting up libsuitesparseconfig5:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up libgudev-1.0-0:amd64 (1:237-2build1) ...
# Setting up fonts-opensymbol (2:102.12+LibO7.3.7-0ubuntu0.22.04.10) ...
# Setting up libservlet3.1-java (1:4.0.1-2) ...
# Setting up libodfgen-0.1-1:amd64 (0.1.8-2build2) ...
# Setting up libvisio-0.1-1:amd64 (0.1.7-1build5) ...
# Setting up libreoffice-style-elementary (1:7.3.7-0ubuntu0.22.04.10) ...
# Setting up fonts-dejavu (2.37-2build1) ...
# Setting up libwps-0.4-4:amd64 (0.4.12-2build1) ...
# Setting up libcolamd2:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up libexttextcat-2.0-0:amd64 (3.4.5-1build2) ...
# Setting up libgpgmepp6:amd64 (1.16.0-1.2ubuntu4.2) ...
# Setting up libmspub-0.1-1:amd64 (0.1.4-3build3) ...
# Setting up libraptor2-0:amd64 (2.0.15-0ubuntu4.1) ...
# Setting up lp-solve (5.5.2.5-2build2) ...
# Setting up libpagemaker-0.0-0:amd64 (0.0.4-1build3) ...
# Setting up libmwaw-0.3-3:amd64 (0.3.21-1build1) ...
# Setting up libcdr-0.1-1:amd64 (0.1.6-2build2) ...
# Setting up liblangtag1:amd64 (0.6.3-2ubuntu1) ...
# Setting up libfbclient2:amd64 (3.0.8.33535.ds4-1ubuntu2) ...
# Setting up libatk-wrapper-java-jni:amd64 (0.38.0-5build1) ...
# Setting up liborcus-0.17-0:amd64 (0.17.2-2) ...
# Setting up libgstreamer-gl1.0-0:amd64 (1.20.1-1ubuntu0.5) ...
# Setting up firebird3.0-utils (3.0.8.33535.ds4-1ubuntu2) ...
# Setting up libuno-cppu3 (1:7.3.7-0ubuntu0.22.04.10) ...
# Setting up libhsqldb1.8.0-java (1.8.0.10+dfsg-11) ...
# Setting up libclucene-contribs1v5:amd64 (2.3.3.4+dfsg-1ubuntu5) ...
# Setting up libwpg-0.3-3:amd64 (0.3.3-1build3) ...
# Setting up libxmlsec1-nss:amd64 (1.2.33-1build2) ...
# Setting up gstreamer1.0-gl:amd64 (1.20.1-1ubuntu0.5) ...
# Setting up libuno-purpenvhelpergcc3-3 (1:7.3.7-0ubuntu0.22.04.10) ...
# Setting up uno-libs-private (1:7.3.7-0ubuntu0.22.04.10) ...
# Setting up firebird3.0-server-core:amd64 (3.0.8.33535.ds4-1ubuntu2) ...
# Setting up librasqal3:amd64 (0.9.33-0.2ubuntu1) ...
# Setting up libetonyek-0.1-1:amd64 (0.1.10-3build1) ...
# Setting up gstreamer1.0-gtk3:amd64 (1.20.3-0ubuntu1.4) ...
# Setting up libe-book-0.1-1:amd64 (0.1.3-2build2) ...
# Setting up librdf0:amd64 (1.0.17-1.1ubuntu3) ...
# Setting up libuno-cppuhelpergcc3-3 (1:7.3.7-0ubuntu0.22.04.10) ...
# Setting up ure (1:7.3.7-0ubuntu0.22.04.10) ...
# Setting up libreoffice-common (1:7.3.7-0ubuntu0.22.04.10) ...
#
# Creating config file /etc/libreoffice/registry/main.xcd with new version
#
# Creating config file /etc/libreoffice/registry/pdfimport.xcd with new version
#
# Creating config file /etc/libreoffice/registry/xsltfilter.xcd with new version
#
# Creating config file /etc/libreoffice/registry/lingucomponent.xcd with new version
#
# Creating config file /etc/libreoffice/registry/Langpack-en-US.xcd with new version
#
# Creating config file /etc/libreoffice/registry/res/fcfg_langpack_en-US.xcd with new version
# Setting up ure-java (1:7.3.7-0ubuntu0.22.04.10) ...
# Setting up libreoffice-core (1:7.3.7-0ubuntu0.22.04.10) ...
# Setting up libreoffice-math (1:7.3.7-0ubuntu0.22.04.10) ...
#
# Creating config file /etc/libreoffice/registry/math.xcd with new version
# Setting up libreoffice-gtk3 (1:7.3.7-0ubuntu0.22.04.10) ...
# Setting up libreoffice-sdbc-postgresql (1:7.3.7-0ubuntu0.22.04.10) ...
#
# Creating config file /etc/libreoffice/registry/postgresql.xcd with new version
# Setting up liblibreoffice-java (1:7.3.7-0ubuntu0.22.04.10) ...
# Setting up libreoffice-draw (1:7.3.7-0ubuntu0.22.04.10) ...
#
# Creating config file /etc/libreoffice/registry/draw.xcd with new version
#
# Creating config file /etc/libreoffice/registry/graphicfilter.xcd with new version
# Setting up libreoffice-java-common (1:7.3.7-0ubuntu0.22.04.10) ...
# Setting up libreoffice-base-drivers (1:7.3.7-0ubuntu0.22.04.10) ...
# Setting up libreoffice-wiki-publisher (1.2.0+LibO7.3.7-0ubuntu0.22.04.10) ...
# Setting up libreoffice-sdbc-firebird (1:7.3.7-0ubuntu0.22.04.10) ...
# Setting up libreoffice-sdbc-mysql (1:7.3.7-0ubuntu0.22.04.10) ...
# Setting up libreoffice-gnome (1:7.3.7-0ubuntu0.22.04.10) ...
#
# Creating config file /etc/libreoffice/registry/gnome.xcd with new version
# Setting up libreoffice-impress (1:7.3.7-0ubuntu0.22.04.10) ...
#
# Creating config file /etc/libreoffice/registry/impress.xcd with new version
#
# Creating config file /etc/libreoffice/registry/ogltrans.xcd with new version
# Setting up libreoffice-base-core (1:7.3.7-0ubuntu0.22.04.10) ...
# Setting up python3-uno (1:7.3.7-0ubuntu0.22.04.10) ...
#
# Creating config file /etc/libreoffice/registry/pyuno.xcd with new version
# Setting up libreoffice-script-provider-bsh (1:7.3.7-0ubuntu0.22.04.10) ...
# Setting up libreoffice-script-provider-js (1:7.3.7-0ubuntu0.22.04.10) ...
# Setting up libreoffice-calc (1:7.3.7-0ubuntu0.22.04.10) ...
#
# Creating config file /etc/libreoffice/registry/calc.xcd with new version
# Setting up libreoffice-base (1:7.3.7-0ubuntu0.22.04.10) ...
#
# Creating config file /etc/libreoffice/registry/base.xcd with new version
# Setting up libreoffice-sdbc-hsqldb (1:7.3.7-0ubuntu0.22.04.10) ...
# Setting up libreoffice-writer (1:7.3.7-0ubuntu0.22.04.10) ...
#
# Creating config file /etc/libreoffice/registry/writer.xcd with new version
# Setting up libreoffice-script-provider-python (1:7.3.7-0ubuntu0.22.04.10) ...
# Setting up libreoffice-nlpsolver (0.9+LibO7.3.7-0ubuntu0.22.04.10) ...
# Setting up libreoffice-report-builder-bin (1:7.3.7-0ubuntu0.22.04.10) ...
# Setting up libreoffice (1:7.3.7-0ubuntu0.22.04.10) ...
# Setting up libreoffice-report-builder (1:7.3.7-0ubuntu0.22.04.10) ...
#
# Creating config file /etc/libreoffice/registry/reportbuilder.xcd with new version
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for shared-mime-info (2.1-2) ...
# Processing triggers for mailcap (3.70+nmu1ubuntu1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# Processing triggers for dictionaries-common (1.28.14) ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 82.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.1/24.1 MB 60.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 kB 20.1 MB/s eta 0:00:00

# %%
import json, time, re, unicodedata
from datetime import datetime
from urllib.parse import urljoin
import requests
from bs4 import BeautifulSoup

BASE_HOST  = "https://registrai.lt"
LIST_URL   = f"{BASE_HOST}/management/search/search_result/"
LOGIN_URL  = f"{BASE_HOST}/login/do_login"
TIMEOUT    = 30
DELAY_S    = 0.35
MIN_YEAR   = 2015

HEADERS = {
    "User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0 Safari/537.36",
}

def nrm(s: str) -> str:
    s = unicodedata.normalize("NFD", s or "")
    s = "".join(ch for ch in s if not unicodedata.combining(ch))
    s = re.sub(r"\s+", " ", s).strip().lower()
    return s

def parse_date(text: str):
    text = (text or "").strip()
    for fmt in ("%Y-%m-%d", "%Y.%m.%d", "%Y/%m/%d", "%d.%m.%Y", "%d-%m-%Y"):
        try:
            return datetime.strptime(text, fmt).date()
        except Exception:
            pass
    m = re.search(r"(19|20)\d{2}[-./](0?[1-9]|1[0-2])[-./](0?[1-9]|[12]\d|3[01])", text)
    if m:
        t = m.group(0).replace(".", "-").replace("/", "-")
        try:
            return datetime.strptime(t, "%Y-%m-%d").date()
        except Exception:
            return None
    return None

def fetch_html(sess: requests.Session, url: str) -> str:
    try:
        response = sess.get(url, headers=HEADERS, timeout=TIMEOUT, allow_redirects=True)
        response.raise_for_status()
        return response.text
    except requests.RequestException as e:
        print(f"Error fetching page content: {e}")
        return None

def guest_accept(sess: requests.Session):
    """Accept the public data license as a guest to unlock the listing."""
    # This mirrors the left form in the HTML: hidden guest=1 + checkbox accept_license
    data = {
        "guest": "1",
        "accept_license": "1",
        "guest_submit": "Duomenų peržiūra"
    }
    r = sess.post(LOGIN_URL, headers=HEADERS, data=data, timeout=TIMEOUT, allow_redirects=True)
    r.raise_for_status()
    time.sleep(DELAY_S)

def find_results_table(soup: BeautifulSoup):
    for tbl in soup.find_all("table"):
        head_tr = tbl.find("tr")
        if not head_tr:
            continue
        headers = [th.get_text(" ", strip=True) for th in head_tr.find_all(["th","td"])]
        H = [nrm(h) for h in headers]
        if any("bendra informacija: pavadinimas" in h for h in H) and \
           any("bendra informacija: iregistravimo data" in h for h in H) and \
           any("bendra informacija: specifikacija" in h for h in H):
            return tbl
    return None

def get_col_indices(table):
    head_tr = table.find("tr")
    headers = [th.get_text(" ", strip=True) for th in head_tr.find_all(["th","td"])]
    title_idx = date_idx = spec_idx = None
    for i, h in enumerate(headers):
        hn = nrm(h)
        if "bendra informacija: pavadinimas" in hn:
            title_idx = i
        elif "bendra informacija: iregistravimo data" in hn:  # Į -> i after normalization
            date_idx = i
        elif "bendra informacija: specifikacija" in hn:
            spec_idx = i
    return title_idx, date_idx, spec_idx

def parse_list_page(html: str, base_for_links: str):
    soup = BeautifulSoup(html, "html.parser")
    table = find_results_table(soup)
    if not table:
        return [], None

    title_idx, date_idx, spec_idx = get_col_indices(table)
    if None in (title_idx, date_idx, spec_idx):
        return [], None

    items = []
    # Work with article row
    for tr in table.select("tr.elements, tr.erow.elements"):
        tds = tr.find_all("td")
        if len(tds) <= max(title_idx, date_idx, spec_idx):
            continue

        # keep only rows with Specifikacija = Taip (green check)
        spec_td = tds[spec_idx]
        has_spec = any(
            (img.get("alt","").strip().lower() == "taip") or ("accept.png" in (img.get("src","") or "").lower())
            for img in spec_td.find_all("img")
        )
        if not has_spec:
            continue

        # title + link
        a = tds[title_idx].find("a", href=True)
        if not a:
            continue
        title = a.get_text(" ", strip=True)
        link = urljoin(base_for_links, a["href"])

        # date
        d = parse_date(tds[date_idx].get_text(" ", strip=True))
        if not d or d.year < MIN_YEAR:
            continue

        items.append({
            "title": title,
            "date": d.isoformat(),
            "link": link
        })

    # pagination → find the link right after the current page
    next_url = None
    pag = soup.find("div", class_="pagination")
    if pag:
        links = pag.find_all("a")
        cur_i = None
        for i, a in enumerate(links):
            if a.get("id") == "pagination_current":
                cur_i = i; break
        if cur_i is not None and cur_i + 1 < len(links):
            href = links[cur_i + 1].get("href")
            if href and href != "#":
                next_url = urljoin(base_for_links, href)
    return items, next_url

def main():
    sess = requests.Session()
    # 1) Accept the license as guest
    try:
        guest_accept(sess)
    except Exception as e:
        print(f"[WARN] Guest accept failed (continuing): {e}")

    # 2) Crawl listing pages
    url = LIST_URL
    results = []
    pages = 0
    while url:
        try:
            html = fetch_html(sess, url)
        except Exception as e:
            print(f"[HTTP] {e} @ {url}")
            break

        rows, next_url = parse_list_page(html, url)
        print(f"[DEBUG] Parsed {len(rows)} rows on this page")
        results.extend(rows)
        url = next_url
        pages += 1
        time.sleep(DELAY_S)

    with open("registrai_output.json", "w", encoding="utf-8") as f:
        json.dump(results, f, ensure_ascii=False, indent=2)

    print(f"Done. Saved {len(results)} items to registrai_output.json")

if __name__ == "__main__":
    main()
# Out:
# [DEBUG] Parsed 4 rows on this page
# [DEBUG] Parsed 11 rows on this page
# [DEBUG] Parsed 9 rows on this page
# [DEBUG] Parsed 19 rows on this page
# [DEBUG] Parsed 16 rows on this page
# [DEBUG] Parsed 16 rows on this page
# [DEBUG] Parsed 0 rows on this page
# [DEBUG] Parsed 0 rows on this page
# [DEBUG] Parsed 0 rows on this page
# [DEBUG] Parsed 0 rows on this page
# [DEBUG] Parsed 0 rows on this page
# [DEBUG] Parsed 0 rows on this page
# [DEBUG] Parsed 0 rows on this page
# [DEBUG] Parsed 0 rows on this page
# [DEBUG] Parsed 0 rows on this page
# [DEBUG] Parsed 0 rows on this page
# [DEBUG] Parsed 0 rows on this page
# [DEBUG] Parsed 0 rows on this page
# Done. Saved 75 items to registrai_output.json

# %%
import shutil
import os

# Path to the downloaded_articles directory
OUTPUT_DIR = "downloaded_articles"

# Check if the directory exists
if os.path.exists(OUTPUT_DIR):
    # Delete the directory and all its contents
    shutil.rmtree(OUTPUT_DIR)
    print(f"Cleared '{OUTPUT_DIR}' directory.")

# Recreate the directory
os.makedirs(OUTPUT_DIR, exist_ok=True)
print(f"Recreated '{OUTPUT_DIR}' directory.")
# Out:
# Cleared 'downloaded_articles' directory.
# Recreated 'downloaded_articles' directory.

# %%
# =======================
# Phase 2 — Fetch Specifikacija docs (metadata + original files)
# Output JSON:
# [
#   {
#     "title": "...",
#     "date":  "...",         # from input if present (unchanged)
#     "link":  "...",         # item detail page URL from input
#     "documents": [
#       {"title":"...", "date":"...", "link":"...", "file_format": "..."},
#       ...
#     ]
#   },
#   ...
# ]
# =======================

import os, re, json, time, unicodedata
from urllib.parse import urljoin
from datetime import datetime

import requests
from requests.adapters import HTTPAdapter, Retry
from bs4 import BeautifulSoup

# ---------------- CONFIG ----------------
BASE_HOST  = "https://registrai.lt"
LOGIN_URL  = f"{BASE_HOST}/login/do_login"

IN_JSON    = "registrai_output.json"
OUT_JSON   = "registrai_output_with_docs.json"
OUT_DIR    = "downloaded_articles"   # originals saved here

# Networking
CONNECT_TIMEOUT = 10
READ_TIMEOUT    = 60
TIMEOUT_TUPLE   = (CONNECT_TIMEOUT, READ_TIMEOUT)

RETRIES = Retry(
    total=5, connect=5, read=5,
    backoff_factor=0.8,
    status_forcelist=(429, 500, 502, 503, 504),
    allowed_methods=("GET", "POST"),
    raise_on_status=False,
)

HEADERS = {
    "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0 Safari/537.36",
}

PAUSE_BETWEEN = 0.15

# --------------- UTILS ------------------
def nrm(s: str) -> str:
    s = unicodedata.normalize("NFD", s or "")
    s = "".join(ch for ch in s if not unicodedata.combining(ch))
    s = re.sub(r"\s+", " ", s).strip().lower()
    return s

def safe_filename(name: str) -> str:
    name = re.sub(r"[^\w\s.-]", "_", name, flags=re.UNICODE)
    name = re.sub(r"\s+", "_", name).strip("_")
    return name[:180] or "file"

def parse_date_fuzzy(text: str):
    text = (text or "").strip()
    for fmt in ("%Y-%m-%d", "%Y.%m.%d", "%Y/%m/%d", "%d.%m.%Y", "%d-%m-%Y"):
        try:
            return datetime.strptime(text, fmt).date().isoformat()
        except Exception:
            pass
    m = re.search(r"(19|20)\d{2}[-./](0?[1-9]|1[0-2])[-./](0?[1-9]|[12]\d|3[01])", text)
    if m:
        t = m.group(0).replace(".", "-").replace("/", "-")
        try:
            return datetime.strptime(t, "%Y-%m-%d").date().isoformat()
        except Exception:
            return None
    return None

# ------------- HTTP HELPERS -------------
def make_session():
    s = requests.Session()
    s.headers.update(HEADERS)
    adapter = HTTPAdapter(max_retries=RETRIES, pool_connections=20, pool_maxsize=20)
    s.mount("http://", adapter)
    s.mount("https://", adapter)
    return s

def fetch_html(sess: requests.Session, url: str) -> str:
    r = sess.get(url, timeout=TIMEOUT_TUPLE, allow_redirects=True)
    r.raise_for_status()
    return r.text

def guest_accept(sess: requests.Session):
    data = {"guest":"1","accept_license":"1","guest_submit":"Duomenų peržiūra"}
    r = sess.post(LOGIN_URL, data=data, timeout=TIMEOUT_TUPLE, allow_redirects=True)
    r.raise_for_status()
    time.sleep(0.2)

# ----- Specifikacija tab discovery ------
def find_spec_tab_url(soup: BeautifulSoup, base_url: str):
    """
    Return a URL whose HTML contains the #tab6 (Specifikacija) content.
    """
    a = soup.select_one('a[href="#tab6"], a[aria-controls="tab6"], a[data-target="#tab6"]')
    if a:
        return base_url
    for a in soup.find_all("a", href=True):
        if "specifikacija" in nrm(a.get_text(" ", strip=True)):
            href = a["href"]
            return base_url if href.startswith("#") else urljoin(base_url, href)
    return None

# ---------- Download originals ----------
def guess_ext_from_headers(resp: requests.Response, url: str) -> str:
    cd = resp.headers.get("content-disposition", "")
    m = re.search(r'filename\*=UTF-8\'\'([^;]+)', cd, flags=re.I)
    if not m:
        m = re.search(r'filename="?([^";]+)"?', cd, flags=re.I)
    if m:
        ext = os.path.splitext(m.group(1))[1].lower()
        if ext:
            return ext
    uext = os.path.splitext(url.split("?")[0])[1].lower()
    if uext:
        return uext
    ct = (resp.headers.get("content-type") or "").lower()
    if "pdf" in ct: return ".pdf"
    if "msword" in ct: return ".doc"
    if "officedocument.wordprocessingml.document" in ct: return ".docx"
    if "rtf" in ct: return ".rtf"
    if "html" in ct: return ".html"
    if "asciidoc" in ct or "adoc" in ct: return ".adoc"
    if "plain" in ct: return ".txt"
    return ".bin"

def download_file(sess: requests.Session, url: str, base_folder: str, stub: str) -> str:
    r = sess.get(url, timeout=TIMEOUT_TUPLE, allow_redirects=True, stream=True)
    r.raise_for_status()
    ext = guess_ext_from_headers(r, url)
    os.makedirs(base_folder, exist_ok=True)
    out = os.path.join(base_folder, stub + ext)
    # resume: skip if exists and non-empty
    if os.path.exists(out) and os.path.getsize(out) > 0:
        return out
    with open(out, "wb") as f:
        for chunk in r.iter_content(65536):
            if chunk:
                f.write(chunk)
    return out

# ----- Extract only #tab6 documents -----
def extract_spec_docs(soup_or_html, base_url, sess):
    soup = soup_or_html if isinstance(soup_or_html, BeautifulSoup) else BeautifulSoup(soup_or_html, "html.parser")
    docs = []
    for tbl in soup.select('#tab6 table.details_t'):
        approval_date = None
        title = None
        href = None
        for tr in tbl.select("tr"):
            lbl = tr.find("td", class_="input_label")
            label = lbl.get_text("", strip=True) if lbl else ""
            if "Patvirtinimo data" in label:
                tds = tr.find_all("td")
                if tds:
                    raw = (tds[-1].get_text(" ", strip=True) or "").strip()
                    approval_date = parse_date_fuzzy(raw) or raw or None
            if "Pavadinimas" in label:
                field = tr.find("td", class_="input_field") or (tr.find_all("td")[-1] if tr.find_all("td") else None)
                a = field.find("a", href=True) if field else None
                if a:
                    title = a.get_text(" ", strip=True)
                    href  = urljoin(base_url, a["href"])
                else:
                    title = href = None
        if href:
            file_format = None
            try:
                r = sess.get(href, timeout=TIMEOUT_TUPLE, allow_redirects=True, stream=True)
                r.raise_for_status()
                ext = guess_ext_from_headers(r, href)
                if ext:
                    file_format = ext.lstrip(".").lower()
            except Exception:
                if href.startswith("/"):
                    try:
                        url2 = urljoin(BASE_HOST, href)
                        r = sess.get(url2, timeout=TIMEOUT_TUPLE, allow_redirects=True, stream=True)
                        r.raise_for_status()
                        ext = guess_ext_from_headers(r, url2)
                        if ext:
                            file_format = ext.lstrip(".").lower()
                    except Exception:
                        pass
            finally:
                try:
                    r.close()
                except Exception:
                    pass
            docs.append({"title": title, "date": approval_date, "link": href, "file_format": file_format})

    # de-duplicate by link
    seen, uniq = set(), []
    for d in docs:
        if d["link"] in seen:
            continue
        seen.add(d["link"])
        uniq.append(d)
    return uniq

def process_object(sess: requests.Session, item: dict):
    detail_html = fetch_html(sess, item["link"])
    dsoup = BeautifulSoup(detail_html, "html.parser")

    spec_url = find_spec_tab_url(dsoup, item["link"])
    spec_soup = dsoup
    if spec_url and spec_url != item["link"]:
        spec_html = fetch_html(sess, spec_url)
        spec_soup = BeautifulSoup(spec_html, "html.parser")

    docs = extract_spec_docs(spec_soup, spec_url or item["link"], sess)

    # download originals
    base_folder = os.path.join(OUT_DIR, safe_filename(item.get("title") or "item"))
    os.makedirs(base_folder, exist_ok=True)
    for i, d in enumerate(docs, 1):
        url = d["link"]
        title = d.get("title") or f"document_{i}"
        stub  = f"{safe_filename(title)}"
        try:
            download_file(sess, url, base_folder, stub)
        except Exception:
            if url.startswith("/"):
                try:
                    download_file(sess, urljoin(BASE_HOST, url), base_folder, stub)
                except Exception as e:
                    print(f"   -> download failed: {e}")
            else:
                print(f"   -> download failed: {url}")

    # return only metadata in JSON
    return {
        "title": item.get("title"),
        "date":  item.get("date") or None,
        "link":  item.get("link"),
        "documents": docs
    }

def run_phase2(input_json=IN_JSON, output_json=OUT_JSON):
    with open(input_json, "r", encoding="utf-8") as f:
        rows = json.load(f)

    sess = make_session()
    try:
        guest_accept(sess)
    except Exception as e:
        print(f"[WARN] Guest accept failed (continuing): {e}")

    out = []
    total = len(rows)
    for idx, item in enumerate(rows, 1):
        # refresh session every 20 items
        if idx % 20 == 0:
            try:
                sess.close()
            except Exception:
                pass
            sess = make_session()
            try: guest_accept(sess)
            except Exception: pass

        print(f"[{idx}/{total}] {item.get('title')}")
        try:
            out.append(process_object(sess, item))
        except Exception as e:
            print(f"   -> ERROR: {e}")
            out.append({
                "title": item.get("title"),
                "date":  item.get("date") or None,
                "link":  item.get("link"),
                "documents": []
            })
        time.sleep(PAUSE_BETWEEN)

    with open(output_json, "w", encoding="utf-8") as f:
        json.dump(out, f, ensure_ascii=False, indent=2)
    print(f"Done. Saved {len(out)} items to {output_json}")

if __name__ == "__main__":
    run_phase2()
# Out:
# [1/75] Pastatų duomenų banko informacinė sistema
# [2/75] Biologinės įvairovės informacinė sistema
# [3/75] Teisėjų ir pretendentų į teisėjus informacinė sistema
# [4/75] Nuotekų tvarkymo informacinė sistema
# [5/75] Integruotų paslaugų platforma
# [6/75] Statinių prieinamumo stebėsenos ir kontrolės informacinė sistema
# [7/75] Viešosios įstaigos CPO LT Centralizuotų viešųjų pirkimų vykdymo informacinė sistema
# [8/75] Žemės ūkio veiklą vykdančių ūkio subjektų patikrinimo aktų informacinė sistema
# [9/75] Politinių organizacijų narių registras
# [10/75] Nacionalinė turizmo informacinė sistema
# [11/75] Paramos žemės ūkio veiklos subjektams apskaičiavimo informacinė sistema
# [12/75] Kultūrinės edukacijos informacinė sistema
# [13/75] Lietuvos sveikatos priežiūros specialistų kompetencijų platformos informacinė sistema
# [14/75] Pieno apskaitos informacinė sistema
# [15/75] VšĮ Vilniaus miesto klinikinės ligoninės informacinė sistema
# [16/75] Taikomųjų inovacijų tyrimų ir rezultatų informacinė sistema
# [17/75] Energetikos darbuotojų atestavimo informacinė sistema
# [18/75] Europos pagalbos labiausiai skurstantiems asmenims fondo informacinė sistema
# [19/75] Portfelių ir projektų valdymo informacinė sistema
# [20/75] Transporto priemonių savininkų apskaitos informacinė sistema
# [21/75] Asmens dokumentų išdavimo informacinė sistema
# [22/75] Atvirų finansų informacinė sistema
# [23/75] Topografijos, inžinerinės infrastruktūros, teritorijų planavimo ir statybos elektroninių vartų informacinė sistema
# [24/75] Lietuvos atvirų duomenų portalas
# [25/75] Valstybės informacinių technologijų paslaugų valdymo informacinė sistema
# [26/75] Metrikacijos ir gyvenamosios vietos deklaravimo informacinė sistema
# [27/75] Kelių ir geležinkelių transporto veiklos elektroninių paslaugų teikimo, konsultavimo ir informavimo valstybės informacinė sistema
# [28/75] Všį Dainų pirminės sveikatos priežiūros centro informacinė sistema
# [29/75] Priežiūrą atliekančių institucijų informacinė sistema
# [30/75] Detalios paciento lygio sąnaudų apskaitos informacinė sistema
# [31/75] Bendrojo priėmimo informacinė sistema
# [32/75] Aplinkos projektų valdymo informacinė sistema
# [33/75] 2014–2021 m. Europos ekonominės erdvės ir Norvegijos finansinių mechanizmų administravimo ir procesų automatizavimo informacinė sistema
# [34/75] Viešosios informacijos rengėjų ir skleidėjų informacinė sistema
# [35/75] Elektroninės pripažinimo erdvės informacinė sistema
# [36/75] Informacinė sistema e-kinas
# [37/75] Vidaus reikalų ministerijos medicinos centro informacinė sistema
# [38/75] Topografijos ir inžinerinės infrastruktūros informacinė sistema
# [39/75] Lošimo automatų kontrolės informacinė sistema
# [40/75] Teisinės pagalbos paslaugų informacinė sistema
# [41/75] Žvejybos sektoriaus perleidžiamųjų teisių registro informacinė sistema
# [42/75] Lietuvos erdvinės informacijos portalas
# [43/75] Lietuvos Respublikos globalinės padėties nustatymo sistemos nuolatinių stočių tinklas
# [44/75] Lietuvos Respublikos terminų banko informacinė sistema
# [45/75] Visuomenės sveikatos stebėsenos informacinė sistema
# [46/75] Valstybinės ir vietinės reikšmės kelių turto valdymo informacinė sistema
# [47/75] Supaprastinto tranzito dokumentų informacinė sistema
# [48/75] Lietuvos migracijos informacinė sistema
# [49/75] Pasipriešinimo okupacijoms dalyviai
# [50/75] Asmenys, nukentėję nuo okupacijų
# [51/75] Traktorininko pažymėjimų informacinė sistema
# [52/75] Statybos sutarčių įvykdymo priežiūros informacinė sistema
# [53/75] Aplinkos projektų monitoringo informacinė sistema
# [54/75] Viešosios įstaigos Visagino pirminės sveikatos priežiūros centro informacinė sistema
# [55/75] Viešosios įstaigos Naujosios Vilnios poliklinikos informacinė sistema
# [56/75] Apribojusių savo galimybę lošti asmenų registras
# [57/75] Vėžio registras
# [58/75] Švietimo portalo informacinė sistema
# [59/75] Valstybinės augalininkystės tarnybos prie žemės ūkio ministerijos informacinė sistema
# [60/75] Viešųjų ir administracinių paslaugų stebėsenos ir analizės informacinė sistema
# [61/75] Elektroninio stebėjimo informacinė sistema
# [62/75] Ūkinių gyvūnų veislininkystės informacinė sistema
# [63/75] Gyvūnų augintinių registras
# [64/75] Visuomenės sveikatos priežiūros specialistų registras
# [65/75] Eilių ir atsargų valdymo informacinė sistema
# [66/75] Nacionalinės elektroninės atpažinties informacinė sistema
# [67/75] Eismo įvykių informacinė sistema
# [68/75] Vaikų sveikatos stebėsenos informacinė sistema
# [69/75] Techninės pagalbos priemonių apskaitos informacinė sistema
# [70/75] Policijos licencijuojamos veiklos informacinė sistema
# [71/75] Elektros energijos kainų palyginimo informacinė sistema
# [72/75] Išmanioji mokesčių administravimo informacinė sistema
# [73/75] Sveikatos priežiūros technologijų, susijusių su medicinos prietaisais, valdymo informacinė sistema
# [74/75] Švietimo įstaigų (išskyrus aukštąsias mokyklas) vadovų informacinė sistema
# [75/75] Nėščiųjų, gimdyvių ir naujagimių sveikatos duomenų tvarkymo informacinė sistema
# Done. Saved 75 items to registrai_output_with_docs.json

# %%
import json
from collections import Counter

IN_JSON = "registrai_output_with_docs.json"

def normalize(fmt):
    if not isinstance(fmt, str):
        return None
    fmt = fmt.strip().lstrip(".").lower()
    return fmt or None

def main():
    with open(IN_JSON, "r", encoding="utf-8") as f:
        data = json.load(f)

    counter = Counter()
    for item in data:
        for doc in item.get("documents", []):
            fmt = normalize(doc.get("file_format"))
            if fmt:
                counter[fmt] += 1

    distinct_formats = sorted(counter.keys())

    print("Distinct file formats:")
    for fmt in distinct_formats:
        print(f"- {fmt}")

    print("\nCounts:")
    for fmt, cnt in counter.most_common():
        print(f"{fmt}: {cnt}")

if __name__ == "__main__":
    main()
# Out:
# Distinct file formats:
# - adoc
# - docx
# - pdf
#
# Counts:
# pdf: 72
# docx: 28
# adoc: 8

# %%
import shutil
import os

# Path to the downloaded_articles directory
OUTPUT_DIR = "downloaded_articles_txt"

# Check if the directory exists
if os.path.exists(OUTPUT_DIR):
    # Delete the directory and all its contents
    shutil.rmtree(OUTPUT_DIR)
    print(f"Cleared '{OUTPUT_DIR}' directory.")

# Recreate the directory
os.makedirs(OUTPUT_DIR, exist_ok=True)
print(f"Recreated '{OUTPUT_DIR}' directory.")
# Out:
# Cleared 'downloaded_articles_txt' directory.
# Recreated 'downloaded_articles_txt' directory.

# %%
# =======================
# Phase 3 — Convert originals to TXT and build final JSON (3 batches of 25)
# Batches: items 1-25, 26-50, 51-75
# Writes per-batch JSON checkpoints and a final merged JSON.
# Output JSON:
# [
#   {
#     "title": "...",
#     "date":  "...",         # from input if present (unchanged)
#     "link":  "...",         # item detail page URL from input
#     "documents": [
#       {"title":"...", "date":"...", "text":"..."},
#       ...
#     ]
#   },
#   ...
# ]
# =======================

import os, re, json, glob, mimetypes, tempfile, pathlib, math, gc, io, zipfile
from urllib.parse import urlparse
import requests
from requests.adapters import HTTPAdapter, Retry
from bs4 import BeautifulSoup
from pdfminer.high_level import extract_text as pdfminer_extract
from pdf2image import convert_from_bytes
import pytesseract
import docx2txt
import chardet

# ---------- Paths ----------
IN_JSON  = "registrai_output_with_docs.json"
IN_DIR   = "downloaded_articles"       # originals from Step 2
OUT_JSON = "registrai_output_texts.json"
OUT_DIR  = "downloaded_articles_txt"   # TXT output

os.makedirs(OUT_DIR, exist_ok=True)
os.makedirs(IN_DIR, exist_ok=True)

# ---------- Config ----------
OCR_LANG        = "eng+lit"   # Lithuanian + English OCR
CONNECT_TIMEOUT = 10
READ_TIMEOUT    = 120
TIMEOUT_TUPLE   = (CONNECT_TIMEOUT, READ_TIMEOUT)

# ---------- Session / cookie reuse (optional for fallback download if you add it later) ----------
def _parse_cookie_string(cookie_str: str):
    jar = {}
    if not cookie_str: return jar
    for part in cookie_str.split(";"):
        if "=" in part:
            k, v = part.strip().split("=", 1)
            jar[k.strip()] = v.strip()
    return jar

def make_session():
    if "CRAWL_SESSION" in globals():
        s = globals()["CRAWL_SESSION"]
    else:
        s = requests.Session()

    retries = Retry(
        total=5, connect=5, read=5,
        backoff_factor=0.6,
        status_forcelist=[429, 500, 502, 503, 504],
        allowed_methods=["GET", "HEAD", "OPTIONS"],
        raise_on_status=False,
    )
    s.mount("http://", HTTPAdapter(max_retries=retries))
    s.mount("https://", HTTPAdapter(max_retries=retries))

    default_headers = {
        "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36",
        "Accept": "*/*",
        "Accept-Language": "lt-LT,lt;q=0.9,en-US;q=0.8,en;q=0.7",
        "DNT": "1",
        "Cache-Control": "no-cache",
        "Pragma": "no-cache",
    }
    s.headers.update(default_headers)

    if "CRAWL_HEADERS" in globals() and isinstance(globals()["CRAWL_HEADERS"], dict):
        s.headers.update(globals()["CRAWL_HEADERS"])

    cookies_from_globals = {}
    if "CRAWL_COOKIES" in globals() and isinstance(globals()["CRAWL_COOKIES"], dict):
        cookies_from_globals.update(globals()["CRAWL_COOKIES"])
    if "CRAWL_COOKIES_STR" in globals() and isinstance(globals()["CRAWL_COOKIES_STR"], str):
        cookies_from_globals.update(_parse_cookie_string(globals()["CRAWL_COOKIES_STR"]))
    for k, v in cookies_from_globals.items():
        try: s.cookies.set(k, v)
        except Exception: pass

    return s

# ---------- Name helpers ----------
def safe_dirname(s: str) -> str:
    s = (s or "").strip()
    s = re.sub(r"[^\w\s.-]", "_", s)
    s = re.sub(r"\s+", "_", s).strip("_")
    return s[:180] or "item"

def safe_filename(name: str) -> str:
    name = re.sub(r"[^\w\s.-]", "_", name, flags=re.UNICODE)
    name = re.sub(r"\s+", "_", name).strip("_")
    return name[:180] or "file"

# ---------- Discovery: local file for a given doc ----------
def find_local_original(base_raw_dir: str, doc_title: str):
    if not os.path.isdir(base_raw_dir):
        return None
    stub = safe_filename(doc_title)
    cand = glob.glob(os.path.join(base_raw_dir, f"{stub}.*"))
    if cand:
        cand.sort(key=lambda p: (os.path.getsize(p), os.path.getmtime(p)), reverse=True)
        return cand[0]
    cand = glob.glob(os.path.join(base_raw_dir, f"{stub}*"))
    if cand:
        cand.sort(key=lambda p: (os.path.getsize(p), os.path.getmtime(p)), reverse=True)
        return cand[0]
    return None


def extract_text_from_pdf_bytes(data: bytes, ocr_lang: str = OCR_LANG):
    """
    Order:
      1) OCR FIRST (streaming, page-by-page via PyMuPDF)
      2) pdftotext (Poppler)
      3) pdfminer
    Returns: (text, method, pages_ocr'ed)
    """
    # --- 1) OCR-first, streaming with PyMuPDF ---
    ocr_text, ocr_pages = "", 0
    try:
        import fitz  # PyMuPDF
        from PIL import Image
        import pytesseract as _pyt
        dpi = 250
        zoom = dpi / 72.0
        mat = fitz.Matrix(zoom, zoom)

        doc = fitz.open(stream=data, filetype="pdf")
        parts = []
        for pno in range(len(doc)):
            try:
                page = doc.load_page(pno)
                # If a page already has a decent text layer, use it
                txt_layer = page.get_text("text") or ""
                if len(txt_layer.strip()) >= 100:
                    parts.append(txt_layer)
                else:
                    pix = page.get_pixmap(matrix=mat, alpha=False)
                    img = Image.frombytes("RGB", [pix.width, pix.height], pix.samples)
                    t = _pyt.image_to_string(img, lang=ocr_lang) or ""
                    if not t.strip():
                        t = f"[[UNREADABLE_PAGE_{pno+1}]]"
                    parts.append(t)
                ocr_pages += 1
                if (pno + 1) % 2 == 0:
                    print(f"         ... OCR page {pno+1}/{len(doc)}")
            except Exception:
                parts.append(f"[[UNREADABLE_PAGE_{pno+1}]]")
                ocr_pages += 1
        ocr_text = "\n\n".join(parts)
    except Exception as e:
        # If PyMuPDF/PIL/Tesseract isn't available, fall back to nothing for OCR phase
        ocr_text, ocr_pages = "", 0

    # --- 2) pdftotext (Poppler) ---
    pdftotext_txt = ""
    try:
        import subprocess, shutil, tempfile
        if shutil.which("pdftotext"):
            with tempfile.NamedTemporaryFile(suffix=".pdf", delete=False) as tf:
                tf.write(data); tf.flush()
                out = subprocess.check_output(
                    ["pdftotext", "-enc", "UTF-8", "-layout", tf.name, "-"],
                    stderr=subprocess.STDOUT
                )
                pdftotext_txt = out.decode("utf-8", "ignore")
    except Exception:
        pdftotext_txt = ""

    # --- 3) pdfminer ---
    pm_txt = ""
    try:
        from pdfminer.high_level import extract_text as _pdfminer_extract
        with tempfile.NamedTemporaryFile(suffix=".pdf") as tf:
            tf.write(data); tf.flush()
            pm_txt = _pdfminer_extract(tf.name) or ""
    except Exception:
        pm_txt = ""

    # --- Choose the longest result ---
    candidates = [
        ("pdf-ocr-stream", ocr_text),
        ("pdftotext",      pdftotext_txt),
        ("pdfminer",       pm_txt),
    ]
    method, best_text = max(candidates, key=lambda kv: len(kv[1] or ""))

    return best_text, method, ocr_pages


def extract_text_from_docx_bytes(data: bytes):
    with tempfile.TemporaryDirectory() as td:
        p = os.path.join(td, "t.docx")
        with open(p, "wb") as f: f.write(data)
        return (docx2txt.process(p) or "", "docx2txt")

def extract_text_from_doc_bytes(data: bytes):
    with tempfile.TemporaryDirectory() as td:
        inp = os.path.join(td, "t.doc")
        with open(inp, "wb") as f: f.write(data)
        os.system(f'libreoffice --headless --convert-to txt:Text "{inp}" --outdir "{td}" > /dev/null 2>&1')
        txt_path = os.path.join(td, "t.txt")
        if os.path.exists(txt_path):
            with open(txt_path, "r", errors="ignore") as f:
                return f.read(), "libreoffice-doc-txt"
        enc = chardet.detect(data).get("encoding") or "utf-8"
        return data.decode(enc, errors="ignore"), "raw-decode-doc-fallback"

def extract_text_from_html_bytes(data: bytes):
    enc = (chardet.detect(data).get("encoding") or "utf-8").lower()
    html = data.decode(enc, errors="ignore")
    soup = BeautifulSoup(html, "lxml")
    for t in soup(["script","style","noscript","header","footer","nav"]): t.extract()
    text = soup.get_text("\n")
    return re.sub(r"\n{3,}", "\n\n", text).strip(), "html-bs4"

def extract_text_generic_via_libreoffice_bytes(data: bytes, suffix: str):
    with tempfile.TemporaryDirectory() as td:
        inp = os.path.join(td, f"t{suffix or '.bin'}")
        with open(inp, "wb") as f: f.write(data)
        os.system(f'libreoffice --headless --convert-to txt:Text "{inp}" --outdir "{td}" > /dev/null 2>&1')
        txt_path = os.path.join(td, "t.txt")
        if os.path.exists(txt_path):
            with open(txt_path, "r", errors="ignore") as f:
                return f.read(), "libreoffice-generic"
        enc = chardet.detect(data).get("encoding") or "utf-8"
        return data.decode(enc, errors="ignore"), "raw-decode-generic"

def extract_payload_from_adoc_container(data: bytes):
    """
    Lithuanian ADOC-2008 is a ZIP container
    Returns: (payload_bytes, payload_ext, note)
    """
    with zipfile.ZipFile(io.BytesIO(data), "r") as zf:
        names = zf.namelist()
        preferred = [".docx", ".pdf", ".odt", ".rtf", ".doc", ".html", ".htm", ".txt"]
        cands = []
        for n in names:
            if n.endswith("/") or n.startswith(("META-INF/", "metadata/")):
                continue
            ext = os.path.splitext(n)[1].lower()
            try:
                size = zf.getinfo(n).file_size
            except Exception:
                size = 0
            rank = preferred.index(ext) if ext in preferred else len(preferred)
            cands.append((rank, -size, n, ext or ".bin"))
        if not cands:
            return b"", None, "adoc-no-payload"
        cands.sort()
        _, _, chosen, ext = cands[0]
        return zf.read(chosen), ext, f"adoc:{chosen}"

def extract_text_from_adoc_bytes(data: bytes):
    """
    Rare case: a true AsciiDoc *text* mislabeled as ADOC container (.adoc).
    """
    # --- Try asciidoctor -> HTML -> text ---
    try:
        import shutil, subprocess, tempfile
        from bs4 import BeautifulSoup

        if shutil.which("asciidoctor"):
            with tempfile.NamedTemporaryFile(suffix=".adoc", delete=False) as tf:
                tf.write(data)
                tf.flush()
                html = subprocess.check_output(
                    ["asciidoctor", "-b", "html5", "-o", "-", tf.name],
                    stderr=subprocess.STDOUT
                ).decode("utf-8", "ignore")

            soup = BeautifulSoup(html, "lxml")
            for t in soup(["script", "style", "nav", "header", "footer", "noscript"]):
                t.extract()
            text = soup.get_text("\n")
            text = re.sub(r"\n{3,}", "\n\n", text).strip()
            return text, "asciidoctor->html->text"
    except Exception:
        pass

    # --- Fallback: lightweight AsciiDoc markup stripping ---
    enc = (chardet.detect(data).get("encoding") or "utf-8")
    txt = data.decode(enc, errors="ignore")
    txt = re.sub(r'(?m)^\s*:[\w\-\.:]+:.*$', '', txt)
    txt = re.sub(r'\[\[[^\]]+\]\]', '', txt)
    txt = re.sub(r'(?m)^\s*\[#?[A-Za-z0-9_.\-]+\]\s*$', '', txt)
    txt = re.sub(r'<<[^,>]+,\s*([^>]+)>>', r'\1', txt)
    txt = re.sub(r'link:[^\[]+\[([^\]]*)\]', r'\1', txt)
    txt = re.sub(r'image:[^\[]+\[([^\]]*)\]', r'\1', txt)
    txt = re.sub(r'\*([^\*]+)\*', r'\1', txt)
    txt = re.sub(r'_([^_]+)_', r'\1', txt)
    txt = re.sub(r'`([^`]+)`', r'\1', txt)
    txt = re.sub(r'\+\+([^+]+)\+\+', r'\1', txt)
    txt = re.sub(r'#([^#]+)#', r'\1', txt)
    txt = re.sub(r'(?m)^\s*={1,6}\s*(.+?)\s*$', r'\1', txt)
    txt = re.sub(r'(?m)^\s*\[[^\]\n]+\]\s*$', '', txt)
    txt = re.sub(r'(?m)^\s*\|[=\-]{3,}\s*$', '', txt)
    txt = re.sub(r'(?m)^\s*\|\s*', '', txt)
    txt = re.sub(r'\s+\|\s+', '  ', txt)
    txt = re.sub(r'(?ms)^\s*[-\.]{4,}\s*$', '', txt)
    txt = re.sub(r'\n{3,}', '\n\n', txt).strip()
    return txt, "adoc-strip"

def convert_bytes_to_text(data: bytes, ext: str):
    ext_l = (ext or "").lower()
    if ext_l == ".pdf":
        text, method, _pages = extract_text_from_pdf_bytes(data, OCR_LANG)
        return text, method
    if ext_l == ".docx":
        text, method = extract_text_from_docx_bytes(data)
        return text, method
    if ext_l == ".doc":
        text, method = extract_text_from_doc_bytes(data)
        return text, method
    if ext_l in (".html", ".htm"):
        text, method = extract_text_from_html_bytes(data)
        return text, method
    if ext_l == ".txt":
        enc = chardet.detect(data).get("encoding") or "utf-8"
        return data.decode(enc, errors="ignore"), "txt-direct"
    if ext_l == ".adoc":
        # If it looks like ZIP, treat as container and convert the embedded payload
        if data[:4] == b"PK\x03\x04":
            payload, p_ext, note = extract_payload_from_adoc_container(data)
            if p_ext:
                txt, meth = convert_bytes_to_text(payload, p_ext)
                return txt, f"{note}->{meth}"
            enc = chardet.detect(data).get("encoding") or "utf-8"
            return data.decode(enc, errors="ignore"), f"{note}->raw-decode"
        else:
            # True AsciiDoc text
            text, method = extract_text_from_adoc_bytes(data)
            return text, method
    text, method = extract_text_generic_via_libreoffice_bytes(data, ext_l or ".bin")
    return text, method

# ---------- Guess extension ----------
def guess_ext_from_path(path: str):
    return pathlib.Path(path).suffix.lower()

def guess_ext_from_response(content_type: str, url: str) -> str:
    if content_type:
        c = content_type.split(";")[0].strip().lower()
        if c.startswith("application/pdf"): return ".pdf"
        if c.startswith("text/html"): return ".html"
        ext = mimetypes.guess_extension(c)
        if ext: return ext.lower()
    return (pathlib.Path(urlparse(url).path).suffix or ".bin").lower()

def convert_item(item, item_index, total_items):
    sys_title = item.get("title") or f"item_{item_index}"
    sys_link  = item.get("link") or ""
    sys_date  = item.get("date")

    base_txt_dir = os.path.join(OUT_DIR, safe_dirname(sys_title))
    base_raw_dir = os.path.join(IN_DIR,  safe_dirname(sys_title))
    os.makedirs(base_txt_dir, exist_ok=True)

    print(f"   - [{item_index}/{total_items}] {sys_title}")
    out_docs = []

    docs = item.get("documents") or []
    for d in docs:
        dtitle = d.get("title") or "document"
        ddate  = d.get("date")

        stub   = f"{safe_filename(dtitle)}"
        txt_fp = os.path.join(base_txt_dir, stub + ".txt")

        # read local original
        local_path = find_local_original(base_raw_dir, dtitle)

        text, method = "", ""
        if local_path and os.path.isfile(local_path):
            try:
                with open(local_path, "rb") as fbin:
                    data = fbin.read()
                ext = guess_ext_from_path(local_path)
                text, method = convert_bytes_to_text(data, ext)
            except Exception as e:
                method = f"local-convert-error:{e}"
                text = "error text"

        # write TXT
        try:
            with open(txt_fp, "w", encoding="utf-8") as ftxt:
                ftxt.write(text or "")
        except Exception:
            with open(txt_fp, "w", encoding="latin-1", errors="ignore") as ftxt:
                ftxt.write((text or "").encode("latin-1","ignore").decode("latin-1","ignore"))

        out_docs.append({"title": dtitle, "date": ddate, "text": text or "error2 text"})

    return {
        "title": item.get("title"),
        "date":  sys_date,
        "link":  sys_link,
        "documents": out_docs
    }

def run_step3_batched(input_json=IN_JSON, output_json=OUT_JSON, batch_size=25, total_batches=3):
    with open(input_json, "r", encoding="utf-8") as f:
        items = json.load(f)

    # 3 batches of 25 since we have 75 document folders
    batches = []
    start = 0
    for b in range(total_batches):
        end = start + batch_size
        batches.append((start, min(end, len(items))))
        start = end

    sess = make_session()
    all_out = []

    total_items = len(items)
    for bi, (lo, hi) in enumerate(batches, start=1):
        if lo >= hi:
            continue
        print(f"\n=== Batch {bi}/{total_batches}: items {lo+1}–{hi} of {total_items} ===")
        batch_out = []

        for idx in range(lo, hi):
            try:
                rec = convert_item(items[idx], idx+1, total_items)
                batch_out.append(rec)
            except Exception as e:
                print(f"      [WARN] item {idx+1} failed: {e}")
                batch_out.append({
                    "title": items[idx].get("title"),
                    "date":  items[idx].get("date"),
                    "link":  items[idx].get("link"),
                    "documents": []
                })

        # checkpoint per batch
        batch_json_path = f"{os.path.splitext(output_json)[0]}_part{bi}.json"
        with open(batch_json_path, "w", encoding="utf-8") as f:
            json.dump(batch_out, f, ensure_ascii=False, indent=2)
        print(f"   -> Saved batch {bi} checkpoint: {batch_json_path}")

        all_out.extend(batch_out)

        # refresh session between batches
        try: sess.close()
        except Exception: pass
        sess = make_session()
        gc.collect()

    # final merged JSON
    with open(output_json, "w", encoding="utf-8") as f:
        json.dump(all_out, f, ensure_ascii=False, indent=2)
    print(f"\nDone. Wrote merged texts and JSON to {output_json}")

if __name__ == "__main__":
    run_step3_batched()
# Out:
# === Batch 1/3: items 1–25 of 75 ===
#    - [1/75] Pastatų duomenų banko informacinė sistema
#          ... OCR page 2/29
#          ... OCR page 4/29
#          ... OCR page 6/29
#          ... OCR page 8/29
#          ... OCR page 10/29
#          ... OCR page 12/29
#          ... OCR page 14/29
#          ... OCR page 16/29
#          ... OCR page 18/29
#          ... OCR page 20/29
#          ... OCR page 22/29
#          ... OCR page 24/29
#          ... OCR page 26/29
#          ... OCR page 28/29
#    - [2/75] Biologinės įvairovės informacinė sistema
#          ... OCR page 2/51
#          ... OCR page 4/51
#          ... OCR page 6/51
#          ... OCR page 8/51
#          ... OCR page 10/51
#          ... OCR page 12/51
#          ... OCR page 14/51
#          ... OCR page 16/51
#          ... OCR page 18/51
#          ... OCR page 20/51
#          ... OCR page 22/51
#          ... OCR page 24/51
#          ... OCR page 26/51
#          ... OCR page 28/51
#          ... OCR page 30/51
#          ... OCR page 32/51
#          ... OCR page 34/51
#          ... OCR page 36/51
#          ... OCR page 38/51
#          ... OCR page 40/51
#          ... OCR page 42/51
#          ... OCR page 44/51
#          ... OCR page 46/51
#          ... OCR page 48/51
#          ... OCR page 50/51
#    - [3/75] Teisėjų ir pretendentų į teisėjus informacinė sistema
#    - [4/75] Nuotekų tvarkymo informacinė sistema
#          ... OCR page 2/46
#          ... OCR page 4/46
#          ... OCR page 6/46
#          ... OCR page 8/46
#          ... OCR page 10/46
#          ... OCR page 12/46
#          ... OCR page 14/46
#          ... OCR page 16/46
#          ... OCR page 18/46
#          ... OCR page 20/46
#          ... OCR page 22/46
#          ... OCR page 24/46
#          ... OCR page 26/46
#          ... OCR page 28/46
#          ... OCR page 30/46
#          ... OCR page 32/46
#          ... OCR page 34/46
#          ... OCR page 36/46
#          ... OCR page 38/46
#          ... OCR page 40/46
#          ... OCR page 42/46
#          ... OCR page 44/46
#          ... OCR page 46/46
#    - [5/75] Integruotų paslaugų platforma
#    - [6/75] Statinių prieinamumo stebėsenos ir kontrolės informacinė sistema
#          ... OCR page 2/45
#          ... OCR page 4/45
#          ... OCR page 6/45
#          ... OCR page 8/45
#          ... OCR page 10/45
#          ... OCR page 12/45
#          ... OCR page 14/45
#          ... OCR page 16/45
#          ... OCR page 18/45
#          ... OCR page 20/45
#          ... OCR page 22/45
#          ... OCR page 24/45
#          ... OCR page 26/45
#          ... OCR page 28/45
#          ... OCR page 30/45
#          ... OCR page 32/45
#          ... OCR page 34/45
#          ... OCR page 36/45
#          ... OCR page 38/45
#          ... OCR page 40/45
#          ... OCR page 42/45
#          ... OCR page 44/45
#    - [7/75] Viešosios įstaigos CPO LT Centralizuotų viešųjų pirkimų vykdymo informacinė sistema
#    - [8/75] Žemės ūkio veiklą vykdančių ūkio subjektų patikrinimo aktų informacinė sistema
#    - [9/75] Politinių organizacijų narių registras
#          ... OCR page 2/80
#          ... OCR page 4/80
#          ... OCR page 6/80
#          ... OCR page 8/80
#          ... OCR page 10/80
#          ... OCR page 12/80
#          ... OCR page 14/80
#          ... OCR page 16/80
#          ... OCR page 18/80
#          ... OCR page 20/80
#          ... OCR page 22/80
#          ... OCR page 24/80
#          ... OCR page 26/80
#          ... OCR page 28/80
#          ... OCR page 30/80
#          ... OCR page 32/80
#          ... OCR page 34/80
#          ... OCR page 36/80
#          ... OCR page 38/80
#          ... OCR page 40/80
#          ... OCR page 42/80
#          ... OCR page 44/80
#          ... OCR page 46/80
#          ... OCR page 48/80
#          ... OCR page 50/80
#          ... OCR page 52/80
#          ... OCR page 54/80
#          ... OCR page 56/80
#          ... OCR page 58/80
#          ... OCR page 60/80
#          ... OCR page 62/80
#          ... OCR page 64/80
#          ... OCR page 66/80
#          ... OCR page 68/80
#          ... OCR page 70/80
#          ... OCR page 72/80
#          ... OCR page 74/80
#          ... OCR page 76/80
#          ... OCR page 78/80
#          ... OCR page 80/80
#    - [10/75] Nacionalinė turizmo informacinė sistema
#    - [11/75] Paramos žemės ūkio veiklos subjektams apskaičiavimo informacinė sistema
#    - [12/75] Kultūrinės edukacijos informacinė sistema
#          ... OCR page 2/32
#          ... OCR page 4/32
#          ... OCR page 6/32
#          ... OCR page 8/32
#          ... OCR page 10/32
#          ... OCR page 12/32
#          ... OCR page 14/32
#          ... OCR page 16/32
#          ... OCR page 18/32
#          ... OCR page 20/32
#          ... OCR page 22/32
#          ... OCR page 24/32
#          ... OCR page 26/32
#          ... OCR page 28/32
#          ... OCR page 30/32
#          ... OCR page 32/32
#    - [13/75] Lietuvos sveikatos priežiūros specialistų kompetencijų platformos informacinė sistema
#          ... OCR page 2/68
#          ... OCR page 4/68
#          ... OCR page 6/68
#          ... OCR page 8/68
#          ... OCR page 10/68
#          ... OCR page 12/68
#          ... OCR page 14/68
#          ... OCR page 16/68
#          ... OCR page 18/68
#          ... OCR page 20/68
#          ... OCR page 22/68
#          ... OCR page 24/68
#          ... OCR page 26/68
#          ... OCR page 28/68
#          ... OCR page 30/68
#          ... OCR page 32/68
#          ... OCR page 34/68
#          ... OCR page 36/68
#          ... OCR page 38/68
#          ... OCR page 40/68
#          ... OCR page 42/68
#          ... OCR page 44/68
#          ... OCR page 46/68
#          ... OCR page 48/68
#          ... OCR page 50/68
#          ... OCR page 52/68
#          ... OCR page 54/68
#          ... OCR page 56/68
#          ... OCR page 58/68
#          ... OCR page 60/68
#          ... OCR page 62/68
#          ... OCR page 64/68
#          ... OCR page 66/68
#          ... OCR page 68/68
#          ... OCR page 2/82
#          ... OCR page 4/82
#          ... OCR page 6/82
#          ... OCR page 8/82
#          ... OCR page 10/82
#          ... OCR page 12/82
#          ... OCR page 14/82
#          ... OCR page 16/82
#          ... OCR page 18/82
#          ... OCR page 20/82
#          ... OCR page 22/82
#          ... OCR page 24/82
#          ... OCR page 26/82
#          ... OCR page 28/82
#          ... OCR page 30/82
#          ... OCR page 32/82
#          ... OCR page 34/82
#          ... OCR page 36/82
#          ... OCR page 38/82
#          ... OCR page 40/82
#          ... OCR page 42/82
#          ... OCR page 44/82
#          ... OCR page 46/82
#          ... OCR page 48/82
#          ... OCR page 50/82
#          ... OCR page 52/82
#          ... OCR page 54/82
#          ... OCR page 56/82
#          ... OCR page 58/82
#          ... OCR page 60/82
#          ... OCR page 62/82
#          ... OCR page 64/82
#          ... OCR page 66/82
#          ... OCR page 68/82
#          ... OCR page 70/82
#          ... OCR page 72/82
#          ... OCR page 74/82
#          ... OCR page 76/82
#          ... OCR page 78/82
#          ... OCR page 80/82
#          ... OCR page 82/82
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P228' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P234' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P240' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P246' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P252' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P258' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P264' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P270' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P272' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P273' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P275' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P277' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P279' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P281' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P285' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P286' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P287' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P288' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P289' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P290' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P292' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P293' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P294' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P295' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P296' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P297' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P299' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P300' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P301' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P302' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P303' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P304' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P310' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P311' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P313' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P315' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P317' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P319' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P323' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P324' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P325' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P326' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P327' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P328' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P330' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P331' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P332' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P333' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P334' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P335' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P337' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P338' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P339' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P340' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P341' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P342' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P344' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P345' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P346' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P347' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P348' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P349' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P351' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P352' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P353' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P354' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P355' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P356' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P358' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P359' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P360' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P361' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P362' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P363' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P365' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P366' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P367' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P368' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P369' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P370' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P372' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P373' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P374' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P375' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P376' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P377' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P379' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P380' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P381' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P382' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P383' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P384' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P386' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P387' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P388' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P389' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P390' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P391' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P393' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P394' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P396' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P398' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P400' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P402' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P406' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P407' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P408' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P409' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P410' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P411' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P413' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P414' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P415' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P416' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P417' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P418' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P483' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P486' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P487' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P490' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P492' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P493' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P495' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P496' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P498' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P500' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P501' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P503' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P504' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P506' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P508' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P509' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P512' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P513' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P516' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P518' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P519' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P522' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P523' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P526' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P528' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P529' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P531' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P532' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P534' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P536' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P537' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P539' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P540' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P542' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P544' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P545' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P547' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P548' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P550' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P552' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P553' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P555' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P556' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P558' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P560' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P561' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P564' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P565' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P568' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P570' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P571' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P573' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P574' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P576' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P578' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P579' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P581' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P582' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P584' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P586' is an invalid float value
#    - [14/75] Pieno apskaitos informacinė sistema
#    - [15/75] VšĮ Vilniaus miesto klinikinės ligoninės informacinė sistema
#          ... OCR page 2/43
#          ... OCR page 4/43
#          ... OCR page 6/43
#          ... OCR page 8/43
#          ... OCR page 10/43
#          ... OCR page 12/43
#          ... OCR page 14/43
#          ... OCR page 16/43
#          ... OCR page 18/43
#          ... OCR page 20/43
#          ... OCR page 22/43
#          ... OCR page 24/43
#          ... OCR page 26/43
#          ... OCR page 28/43
#          ... OCR page 30/43
#          ... OCR page 32/43
#          ... OCR page 34/43
#          ... OCR page 36/43
#          ... OCR page 38/43
#          ... OCR page 40/43
#          ... OCR page 42/43
#    - [16/75] Taikomųjų inovacijų tyrimų ir rezultatų informacinė sistema
#    - [17/75] Energetikos darbuotojų atestavimo informacinė sistema
#    - [18/75] Europos pagalbos labiausiai skurstantiems asmenims fondo informacinė sistema
#          ... OCR page 2/42
#          ... OCR page 4/42
#          ... OCR page 6/42
#          ... OCR page 8/42
#          ... OCR page 10/42
#          ... OCR page 12/42
#          ... OCR page 14/42
#          ... OCR page 16/42
#          ... OCR page 18/42
#          ... OCR page 20/42
#          ... OCR page 22/42
#          ... OCR page 24/42
#          ... OCR page 26/42
#          ... OCR page 28/42
#          ... OCR page 30/42
#          ... OCR page 32/42
#          ... OCR page 34/42
#          ... OCR page 36/42
#          ... OCR page 38/42
#          ... OCR page 40/42
#          ... OCR page 42/42
#          ... OCR page 2/37
#          ... OCR page 4/37
#          ... OCR page 6/37
#          ... OCR page 8/37
#          ... OCR page 10/37
#          ... OCR page 12/37
#          ... OCR page 14/37
#          ... OCR page 16/37
#          ... OCR page 18/37
#          ... OCR page 20/37
#          ... OCR page 22/37
#          ... OCR page 24/37
#          ... OCR page 26/37
#          ... OCR page 28/37
#          ... OCR page 30/37
#          ... OCR page 32/37
#          ... OCR page 34/37
#          ... OCR page 36/37
#    - [19/75] Portfelių ir projektų valdymo informacinė sistema
#          ... OCR page 2/32
#          ... OCR page 4/32
#          ... OCR page 6/32
#          ... OCR page 8/32
#          ... OCR page 10/32
#          ... OCR page 12/32
#          ... OCR page 14/32
#          ... OCR page 16/32
#          ... OCR page 18/32
#          ... OCR page 20/32
#          ... OCR page 22/32
#          ... OCR page 24/32
#          ... OCR page 26/32
#          ... OCR page 28/32
#          ... OCR page 30/32
#          ... OCR page 32/32
#    - [20/75] Transporto priemonių savininkų apskaitos informacinė sistema
#          ... OCR page 2/44
#          ... OCR page 4/44
#          ... OCR page 6/44
#          ... OCR page 8/44
#          ... OCR page 10/44
#          ... OCR page 12/44
#          ... OCR page 14/44
#          ... OCR page 16/44
#          ... OCR page 18/44
#          ... OCR page 20/44
#          ... OCR page 22/44
#          ... OCR page 24/44
#          ... OCR page 26/44
#          ... OCR page 28/44
#          ... OCR page 30/44
#          ... OCR page 32/44
#          ... OCR page 34/44
#          ... OCR page 36/44
#          ... OCR page 38/44
#          ... OCR page 40/44
#          ... OCR page 42/44
#          ... OCR page 44/44
#    - [21/75] Asmens dokumentų išdavimo informacinė sistema
#          ... OCR page 2/67
#          ... OCR page 4/67
#          ... OCR page 6/67
#          ... OCR page 8/67
#          ... OCR page 10/67
#          ... OCR page 12/67
#          ... OCR page 14/67
#          ... OCR page 16/67
#          ... OCR page 18/67
#          ... OCR page 20/67
#          ... OCR page 22/67
#          ... OCR page 24/67
#          ... OCR page 26/67
#          ... OCR page 28/67
#          ... OCR page 30/67
#          ... OCR page 32/67
#          ... OCR page 34/67
#          ... OCR page 36/67
#          ... OCR page 38/67
#          ... OCR page 40/67
#          ... OCR page 42/67
#          ... OCR page 44/67
#          ... OCR page 46/67
#          ... OCR page 48/67
#          ... OCR page 50/67
#          ... OCR page 52/67
#          ... OCR page 54/67
#          ... OCR page 56/67
#          ... OCR page 58/67
#          ... OCR page 60/67
#          ... OCR page 62/67
#          ... OCR page 64/67
#          ... OCR page 66/67
#    - [22/75] Atvirų finansų informacinė sistema
#    - [23/75] Topografijos, inžinerinės infrastruktūros, teritorijų planavimo ir statybos elektroninių vartų informacinė sistema
#          ... OCR page 2/320
#          ... OCR page 4/320
#          ... OCR page 6/320
#          ... OCR page 8/320
#          ... OCR page 10/320
#          ... OCR page 12/320
#          ... OCR page 14/320
#          ... OCR page 16/320
#          ... OCR page 18/320
#          ... OCR page 20/320
#          ... OCR page 22/320
#          ... OCR page 24/320
#          ... OCR page 26/320
#          ... OCR page 28/320
#          ... OCR page 30/320
#          ... OCR page 32/320
#          ... OCR page 34/320
#          ... OCR page 36/320
#          ... OCR page 38/320
#          ... OCR page 40/320
#          ... OCR page 42/320
#          ... OCR page 44/320
#          ... OCR page 46/320
#          ... OCR page 48/320
#          ... OCR page 50/320
#          ... OCR page 52/320
#          ... OCR page 54/320
#          ... OCR page 56/320
#          ... OCR page 58/320
#          ... OCR page 60/320
#          ... OCR page 62/320
#          ... OCR page 64/320
#          ... OCR page 66/320
#          ... OCR page 68/320
#          ... OCR page 70/320
#          ... OCR page 72/320
#          ... OCR page 74/320
#          ... OCR page 76/320
#          ... OCR page 78/320
#          ... OCR page 80/320
#          ... OCR page 82/320
#          ... OCR page 84/320
#          ... OCR page 86/320
#          ... OCR page 88/320
#          ... OCR page 90/320
#          ... OCR page 92/320
#          ... OCR page 94/320
#          ... OCR page 96/320
#          ... OCR page 98/320
#          ... OCR page 100/320
#          ... OCR page 102/320
#          ... OCR page 104/320
#          ... OCR page 106/320
#          ... OCR page 108/320
#          ... OCR page 110/320
#          ... OCR page 112/320
#          ... OCR page 114/320
#          ... OCR page 116/320
#          ... OCR page 118/320
#          ... OCR page 120/320
#          ... OCR page 122/320
#          ... OCR page 124/320
#          ... OCR page 126/320
#          ... OCR page 128/320
#          ... OCR page 130/320
#          ... OCR page 132/320
#          ... OCR page 134/320
#          ... OCR page 136/320
#          ... OCR page 138/320
#          ... OCR page 140/320
#          ... OCR page 142/320
#          ... OCR page 144/320
#          ... OCR page 146/320
#          ... OCR page 148/320
#          ... OCR page 150/320
#          ... OCR page 152/320
#          ... OCR page 154/320
#          ... OCR page 156/320
#          ... OCR page 158/320
#          ... OCR page 160/320
#          ... OCR page 162/320
#          ... OCR page 164/320
#          ... OCR page 166/320
#          ... OCR page 168/320
#          ... OCR page 170/320
#          ... OCR page 172/320
#          ... OCR page 174/320
#          ... OCR page 176/320
#          ... OCR page 178/320
#          ... OCR page 180/320
#          ... OCR page 182/320
#          ... OCR page 184/320
#          ... OCR page 186/320
#          ... OCR page 188/320
#          ... OCR page 190/320
#          ... OCR page 192/320
#          ... OCR page 194/320
#          ... OCR page 196/320
#          ... OCR page 198/320
#          ... OCR page 200/320
#          ... OCR page 202/320
#          ... OCR page 204/320
#          ... OCR page 206/320
#          ... OCR page 208/320
#          ... OCR page 210/320
#          ... OCR page 212/320
#          ... OCR page 214/320
#          ... OCR page 216/320
#          ... OCR page 218/320
#          ... OCR page 220/320
#          ... OCR page 222/320
#          ... OCR page 224/320
#          ... OCR page 226/320
#          ... OCR page 228/320
#          ... OCR page 230/320
#          ... OCR page 232/320
#          ... OCR page 234/320
#          ... OCR page 236/320
#          ... OCR page 238/320
#          ... OCR page 240/320
#          ... OCR page 242/320
#          ... OCR page 244/320
#          ... OCR page 246/320
#          ... OCR page 248/320
#          ... OCR page 250/320
#          ... OCR page 252/320
#          ... OCR page 254/320
#          ... OCR page 256/320
#          ... OCR page 258/320
#          ... OCR page 260/320
#          ... OCR page 262/320
#          ... OCR page 264/320
#          ... OCR page 266/320
#          ... OCR page 268/320
#          ... OCR page 270/320
#          ... OCR page 272/320
#          ... OCR page 274/320
#          ... OCR page 276/320
#          ... OCR page 278/320
#          ... OCR page 280/320
#          ... OCR page 282/320
#          ... OCR page 284/320
#          ... OCR page 286/320
#          ... OCR page 288/320
#          ... OCR page 290/320
#          ... OCR page 292/320
#          ... OCR page 294/320
#          ... OCR page 296/320
#          ... OCR page 298/320
#          ... OCR page 300/320
#          ... OCR page 302/320
#          ... OCR page 304/320
#          ... OCR page 306/320
#          ... OCR page 308/320
#          ... OCR page 310/320
#          ... OCR page 312/320
#          ... OCR page 314/320
#          ... OCR page 316/320
#          ... OCR page 318/320
#          ... OCR page 320/320
#    - [24/75] Lietuvos atvirų duomenų portalas
#          ... OCR page 2/79
#          ... OCR page 4/79
#          ... OCR page 6/79
#          ... OCR page 8/79
#          ... OCR page 10/79
#          ... OCR page 12/79
#          ... OCR page 14/79
#          ... OCR page 16/79
#          ... OCR page 18/79
#          ... OCR page 20/79
#          ... OCR page 22/79
#          ... OCR page 24/79
#          ... OCR page 26/79
#          ... OCR page 28/79
#          ... OCR page 30/79
#          ... OCR page 32/79
#          ... OCR page 34/79
#          ... OCR page 36/79
#          ... OCR page 38/79
#          ... OCR page 40/79
#          ... OCR page 42/79
#          ... OCR page 44/79
#          ... OCR page 46/79
#          ... OCR page 48/79
#          ... OCR page 50/79
#          ... OCR page 52/79
#          ... OCR page 54/79
#          ... OCR page 56/79
#          ... OCR page 58/79
#          ... OCR page 60/79
#          ... OCR page 62/79
#          ... OCR page 64/79
#          ... OCR page 66/79
#          ... OCR page 68/79
#          ... OCR page 70/79
#          ... OCR page 72/79
#          ... OCR page 74/79
#          ... OCR page 76/79
#          ... OCR page 78/79
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P180' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P188' is an invalid float value
#    - [25/75] Valstybės informacinių technologijų paslaugų valdymo informacinė sistema
#    -> Saved batch 1 checkpoint: registrai_output_texts_part1.json
#
# === Batch 2/3: items 26–50 of 75 ===
#    - [26/75] Metrikacijos ir gyvenamosios vietos deklaravimo informacinė sistema
#          ... OCR page 2/61
#          ... OCR page 4/61
#          ... OCR page 6/61
#          ... OCR page 8/61
#          ... OCR page 10/61
#          ... OCR page 12/61
#          ... OCR page 14/61
#          ... OCR page 16/61
#          ... OCR page 18/61
#          ... OCR page 20/61
#          ... OCR page 22/61
#          ... OCR page 24/61
#          ... OCR page 26/61
#          ... OCR page 28/61
#          ... OCR page 30/61
#          ... OCR page 32/61
#          ... OCR page 34/61
#          ... OCR page 36/61
#          ... OCR page 38/61
#          ... OCR page 40/61
#          ... OCR page 42/61
#          ... OCR page 44/61
#          ... OCR page 46/61
#          ... OCR page 48/61
#          ... OCR page 50/61
#          ... OCR page 52/61
#          ... OCR page 54/61
#          ... OCR page 56/61
#          ... OCR page 58/61
#          ... OCR page 60/61
#    - [27/75] Kelių ir geležinkelių transporto veiklos elektroninių paslaugų teikimo, konsultavimo ir informavimo valstybės informacinė sistema
#          ... OCR page 2/100
#          ... OCR page 4/100
#          ... OCR page 6/100
#          ... OCR page 8/100
#          ... OCR page 10/100
#          ... OCR page 12/100
#          ... OCR page 14/100
#          ... OCR page 16/100
#          ... OCR page 18/100
#          ... OCR page 20/100
#          ... OCR page 22/100
#          ... OCR page 24/100
#          ... OCR page 26/100
#          ... OCR page 28/100
#          ... OCR page 30/100
#          ... OCR page 32/100
#          ... OCR page 34/100
#          ... OCR page 36/100
#          ... OCR page 38/100
#          ... OCR page 40/100
#          ... OCR page 42/100
#          ... OCR page 44/100
#          ... OCR page 46/100
#          ... OCR page 48/100
#          ... OCR page 50/100
#          ... OCR page 52/100
#          ... OCR page 54/100
#          ... OCR page 56/100
#          ... OCR page 58/100
#          ... OCR page 60/100
#          ... OCR page 62/100
#          ... OCR page 64/100
#          ... OCR page 66/100
#          ... OCR page 68/100
#          ... OCR page 70/100
#          ... OCR page 72/100
#          ... OCR page 74/100
#          ... OCR page 76/100
#          ... OCR page 78/100
#          ... OCR page 80/100
#          ... OCR page 82/100
#          ... OCR page 84/100
#          ... OCR page 86/100
#          ... OCR page 88/100
#          ... OCR page 90/100
#          ... OCR page 92/100
#          ... OCR page 94/100
#          ... OCR page 96/100
#          ... OCR page 98/100
#          ... OCR page 100/100
#    - [28/75] Všį Dainų pirminės sveikatos priežiūros centro informacinė sistema
#          ... OCR page 2/26
#          ... OCR page 4/26
#          ... OCR page 6/26
#          ... OCR page 8/26
#          ... OCR page 10/26
#          ... OCR page 12/26
#          ... OCR page 14/26
#          ... OCR page 16/26
#          ... OCR page 18/26
#          ... OCR page 20/26
#          ... OCR page 22/26
#          ... OCR page 24/26
#          ... OCR page 26/26
#    - [29/75] Priežiūrą atliekančių institucijų informacinė sistema
#          ... OCR page 2/64
#          ... OCR page 4/64
#          ... OCR page 6/64
#          ... OCR page 8/64
#          ... OCR page 10/64
#          ... OCR page 12/64
#          ... OCR page 14/64
#          ... OCR page 16/64
#          ... OCR page 18/64
#          ... OCR page 20/64
#          ... OCR page 22/64
#          ... OCR page 24/64
#          ... OCR page 26/64
#          ... OCR page 28/64
#          ... OCR page 30/64
#          ... OCR page 32/64
#          ... OCR page 34/64
#          ... OCR page 36/64
#          ... OCR page 38/64
#          ... OCR page 40/64
#          ... OCR page 42/64
#          ... OCR page 44/64
#          ... OCR page 46/64
#          ... OCR page 48/64
#          ... OCR page 50/64
#          ... OCR page 52/64
#          ... OCR page 54/64
#          ... OCR page 56/64
#          ... OCR page 58/64
#          ... OCR page 60/64
#          ... OCR page 62/64
#          ... OCR page 64/64
#    - [30/75] Detalios paciento lygio sąnaudų apskaitos informacinė sistema
#    - [31/75] Bendrojo priėmimo informacinė sistema
#          ... OCR page 2/150
#          ... OCR page 4/150
#          ... OCR page 6/150
#          ... OCR page 8/150
#          ... OCR page 10/150
#          ... OCR page 12/150
#          ... OCR page 14/150
#          ... OCR page 16/150
#          ... OCR page 18/150
#          ... OCR page 20/150
#          ... OCR page 22/150
#          ... OCR page 24/150
#          ... OCR page 26/150
#          ... OCR page 28/150
#          ... OCR page 30/150
#          ... OCR page 32/150
#          ... OCR page 34/150
#          ... OCR page 36/150
#          ... OCR page 38/150
#          ... OCR page 40/150
#          ... OCR page 42/150
#          ... OCR page 44/150
#          ... OCR page 46/150
#          ... OCR page 48/150
#          ... OCR page 50/150
#          ... OCR page 52/150
#          ... OCR page 54/150
#          ... OCR page 56/150
#          ... OCR page 58/150
#          ... OCR page 60/150
#          ... OCR page 62/150
#          ... OCR page 64/150
#          ... OCR page 66/150
#          ... OCR page 68/150
#          ... OCR page 70/150
#          ... OCR page 72/150
#          ... OCR page 74/150
#          ... OCR page 76/150
#          ... OCR page 78/150
#          ... OCR page 80/150
#          ... OCR page 82/150
#          ... OCR page 84/150
#          ... OCR page 86/150
#          ... OCR page 88/150
#          ... OCR page 90/150
#          ... OCR page 92/150
#          ... OCR page 94/150
#          ... OCR page 96/150
#          ... OCR page 98/150
#          ... OCR page 100/150
#          ... OCR page 102/150
#          ... OCR page 104/150
#          ... OCR page 106/150
#          ... OCR page 108/150
#          ... OCR page 110/150
#          ... OCR page 112/150
#          ... OCR page 114/150
#          ... OCR page 116/150
#          ... OCR page 118/150
#          ... OCR page 120/150
#          ... OCR page 122/150
#          ... OCR page 124/150
#          ... OCR page 126/150
#          ... OCR page 128/150
#          ... OCR page 130/150
#          ... OCR page 132/150
#          ... OCR page 134/150
#          ... OCR page 136/150
#          ... OCR page 138/150
#          ... OCR page 140/150
#          ... OCR page 142/150
#          ... OCR page 144/150
#          ... OCR page 146/150
#          ... OCR page 148/150
#          ... OCR page 150/150
#    - [32/75] Aplinkos projektų valdymo informacinė sistema
#          ... OCR page 2/12
#          ... OCR page 4/12
#          ... OCR page 6/12
#          ... OCR page 8/12
#          ... OCR page 10/12
#          ... OCR page 12/12
#    - [33/75] 2014–2021 m. Europos ekonominės erdvės ir Norvegijos finansinių mechanizmų administravimo ir procesų automatizavimo informacinė sistema
#          ... OCR page 2/53
#          ... OCR page 4/53
#          ... OCR page 6/53
#          ... OCR page 8/53
#          ... OCR page 10/53
#          ... OCR page 12/53
#          ... OCR page 14/53
#          ... OCR page 16/53
#          ... OCR page 18/53
#          ... OCR page 20/53
#          ... OCR page 22/53
#          ... OCR page 24/53
#          ... OCR page 26/53
#          ... OCR page 28/53
#          ... OCR page 30/53
#          ... OCR page 32/53
#          ... OCR page 34/53
#          ... OCR page 36/53
#          ... OCR page 38/53
#          ... OCR page 40/53
#          ... OCR page 42/53
#          ... OCR page 44/53
#          ... OCR page 46/53
#          ... OCR page 48/53
#          ... OCR page 50/53
#          ... OCR page 52/53
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P211' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P239' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P262' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P285' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P313' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P336' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P359' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P382' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P405' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P428' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P451' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P468' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P469' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P471' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P473' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P477' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P480' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P485' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P495' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P516' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P530' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P533' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P543' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P557' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P567' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P581' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P584' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P594' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P608' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P614' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P615' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P617' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P619' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P622' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P623' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P633' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P649' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P650' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P651' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P652' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P653' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P654' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P662' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P685' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P700' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P701' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P702' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P703' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P704' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P705' is an invalid float value
# ...
#          ... OCR page 22/52
#          ... OCR page 24/52
#          ... OCR page 26/52
#          ... OCR page 28/52
#          ... OCR page 30/52
#          ... OCR page 32/52
#          ... OCR page 34/52
#          ... OCR page 36/52
#          ... OCR page 38/52
#          ... OCR page 40/52
#          ... OCR page 42/52
#          ... OCR page 44/52
#          ... OCR page 46/52
#          ... OCR page 48/52
#          ... OCR page 50/52
#          ... OCR page 52/52
#    - [57/75] Vėžio registras
#    - [58/75] Švietimo portalo informacinė sistema
#    - [59/75] Valstybinės augalininkystės tarnybos prie žemės ūkio ministerijos informacinė sistema
#    - [60/75] Viešųjų ir administracinių paslaugų stebėsenos ir analizės informacinė sistema
#          ... OCR page 2/39
#          ... OCR page 4/39
#          ... OCR page 6/39
#          ... OCR page 8/39
#          ... OCR page 10/39
#          ... OCR page 12/39
#          ... OCR page 14/39
#          ... OCR page 16/39
#          ... OCR page 18/39
#          ... OCR page 20/39
#          ... OCR page 22/39
#          ... OCR page 24/39
#          ... OCR page 26/39
#          ... OCR page 28/39
#          ... OCR page 30/39
#          ... OCR page 32/39
#          ... OCR page 34/39
#          ... OCR page 36/39
#          ... OCR page 38/39
#    - [61/75] Elektroninio stebėjimo informacinė sistema
#          ... OCR page 2/45
#          ... OCR page 4/45
#          ... OCR page 6/45
#          ... OCR page 8/45
#          ... OCR page 10/45
#          ... OCR page 12/45
#          ... OCR page 14/45
#          ... OCR page 16/45
#          ... OCR page 18/45
#          ... OCR page 20/45
#          ... OCR page 22/45
#          ... OCR page 24/45
#          ... OCR page 26/45
#          ... OCR page 28/45
#          ... OCR page 30/45
#          ... OCR page 32/45
#          ... OCR page 34/45
#          ... OCR page 36/45
#          ... OCR page 38/45
#          ... OCR page 40/45
#          ... OCR page 42/45
#          ... OCR page 44/45
#    - [62/75] Ūkinių gyvūnų veislininkystės informacinė sistema
#    - [63/75] Gyvūnų augintinių registras
#          ... OCR page 2/55
#          ... OCR page 4/55
#          ... OCR page 6/55
#          ... OCR page 8/55
#          ... OCR page 10/55
#          ... OCR page 12/55
#          ... OCR page 14/55
#          ... OCR page 16/55
#          ... OCR page 18/55
#          ... OCR page 20/55
#          ... OCR page 22/55
#          ... OCR page 24/55
#          ... OCR page 26/55
#          ... OCR page 28/55
#          ... OCR page 30/55
#          ... OCR page 32/55
#          ... OCR page 34/55
#          ... OCR page 36/55
#          ... OCR page 38/55
#          ... OCR page 40/55
#          ... OCR page 42/55
#          ... OCR page 44/55
#          ... OCR page 46/55
#          ... OCR page 48/55
#          ... OCR page 50/55
#          ... OCR page 52/55
#          ... OCR page 54/55
#    - [64/75] Visuomenės sveikatos priežiūros specialistų registras
#          ... OCR page 2/78
#          ... OCR page 4/78
#          ... OCR page 6/78
#          ... OCR page 8/78
#          ... OCR page 10/78
#          ... OCR page 12/78
#          ... OCR page 14/78
#          ... OCR page 16/78
#          ... OCR page 18/78
#          ... OCR page 20/78
#          ... OCR page 22/78
#          ... OCR page 24/78
#          ... OCR page 26/78
#          ... OCR page 28/78
#          ... OCR page 30/78
#          ... OCR page 32/78
#          ... OCR page 34/78
#          ... OCR page 36/78
#          ... OCR page 38/78
#          ... OCR page 40/78
#          ... OCR page 42/78
#          ... OCR page 44/78
#          ... OCR page 46/78
#          ... OCR page 48/78
#          ... OCR page 50/78
#          ... OCR page 52/78
#          ... OCR page 54/78
#          ... OCR page 56/78
#          ... OCR page 58/78
#          ... OCR page 60/78
#          ... OCR page 62/78
#          ... OCR page 64/78
#          ... OCR page 66/78
#          ... OCR page 68/78
#          ... OCR page 70/78
#          ... OCR page 72/78
#          ... OCR page 74/78
#          ... OCR page 76/78
#          ... OCR page 78/78
#    - [65/75] Eilių ir atsargų valdymo informacinė sistema
#          ... OCR page 2/72
#          ... OCR page 4/72
#          ... OCR page 6/72
#          ... OCR page 8/72
#          ... OCR page 10/72
#          ... OCR page 12/72
#          ... OCR page 14/72
#          ... OCR page 16/72
#          ... OCR page 18/72
#          ... OCR page 20/72
#          ... OCR page 22/72
#          ... OCR page 24/72
#          ... OCR page 26/72
#          ... OCR page 28/72
#          ... OCR page 30/72
#          ... OCR page 32/72
#          ... OCR page 34/72
#          ... OCR page 36/72
#          ... OCR page 38/72
#          ... OCR page 40/72
#          ... OCR page 42/72
#          ... OCR page 44/72
#          ... OCR page 46/72
#          ... OCR page 48/72
#          ... OCR page 50/72
#          ... OCR page 52/72
#          ... OCR page 54/72
#          ... OCR page 56/72
#          ... OCR page 58/72
#          ... OCR page 60/72
#          ... OCR page 62/72
#          ... OCR page 64/72
#          ... OCR page 66/72
#          ... OCR page 68/72
#          ... OCR page 70/72
#          ... OCR page 72/72
#    - [66/75] Nacionalinės elektroninės atpažinties informacinė sistema
#          ... OCR page 2/66
#          ... OCR page 4/66
#          ... OCR page 6/66
#          ... OCR page 8/66
#          ... OCR page 10/66
#          ... OCR page 12/66
#          ... OCR page 14/66
#          ... OCR page 16/66
#          ... OCR page 18/66
#          ... OCR page 20/66
#          ... OCR page 22/66
#          ... OCR page 24/66
#          ... OCR page 26/66
#          ... OCR page 28/66
#          ... OCR page 30/66
#          ... OCR page 32/66
#          ... OCR page 34/66
#          ... OCR page 36/66
#          ... OCR page 38/66
#          ... OCR page 40/66
#          ... OCR page 42/66
#          ... OCR page 44/66
#          ... OCR page 46/66
#          ... OCR page 48/66
#          ... OCR page 50/66
#          ... OCR page 52/66
#          ... OCR page 54/66
#          ... OCR page 56/66
#          ... OCR page 58/66
#          ... OCR page 60/66
#          ... OCR page 62/66
#          ... OCR page 64/66
#          ... OCR page 66/66
#    - [67/75] Eismo įvykių informacinė sistema
#          ... OCR page 2/49
#          ... OCR page 4/49
#          ... OCR page 6/49
#          ... OCR page 8/49
#          ... OCR page 10/49
#          ... OCR page 12/49
#          ... OCR page 14/49
#          ... OCR page 16/49
#          ... OCR page 18/49
#          ... OCR page 20/49
#          ... OCR page 22/49
#          ... OCR page 24/49
#          ... OCR page 26/49
#          ... OCR page 28/49
#          ... OCR page 30/49
#          ... OCR page 32/49
#          ... OCR page 34/49
#          ... OCR page 36/49
#          ... OCR page 38/49
#          ... OCR page 40/49
#          ... OCR page 42/49
#          ... OCR page 44/49
#          ... OCR page 46/49
#          ... OCR page 48/49
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P136' is an invalid float value
#    - [68/75] Vaikų sveikatos stebėsenos informacinė sistema
#          ... OCR page 2/73
#          ... OCR page 4/73
#          ... OCR page 6/73
#          ... OCR page 8/73
#          ... OCR page 10/73
#          ... OCR page 12/73
#          ... OCR page 14/73
#          ... OCR page 16/73
#          ... OCR page 18/73
#          ... OCR page 20/73
#          ... OCR page 22/73
#          ... OCR page 24/73
#          ... OCR page 26/73
#          ... OCR page 28/73
#          ... OCR page 30/73
#          ... OCR page 32/73
#          ... OCR page 34/73
#          ... OCR page 36/73
#          ... OCR page 38/73
#          ... OCR page 40/73
#          ... OCR page 42/73
#          ... OCR page 44/73
#          ... OCR page 46/73
#          ... OCR page 48/73
#          ... OCR page 50/73
#          ... OCR page 52/73
#          ... OCR page 54/73
#          ... OCR page 56/73
#          ... OCR page 58/73
#          ... OCR page 60/73
#          ... OCR page 62/73
#          ... OCR page 64/73
#          ... OCR page 66/73
#          ... OCR page 68/73
#          ... OCR page 70/73
#          ... OCR page 72/73
#          ... OCR page 2/46
#          ... OCR page 4/46
#          ... OCR page 6/46
#          ... OCR page 8/46
#          ... OCR page 10/46
#          ... OCR page 12/46
#          ... OCR page 14/46
#          ... OCR page 16/46
#          ... OCR page 18/46
#          ... OCR page 20/46
#          ... OCR page 22/46
#          ... OCR page 24/46
#          ... OCR page 26/46
#          ... OCR page 28/46
#          ... OCR page 30/46
#          ... OCR page 32/46
#          ... OCR page 34/46
#          ... OCR page 36/46
#          ... OCR page 38/46
#          ... OCR page 40/46
#          ... OCR page 42/46
#          ... OCR page 44/46
#          ... OCR page 46/46
#    - [69/75] Techninės pagalbos priemonių apskaitos informacinė sistema
#          ... OCR page 2/78
#          ... OCR page 4/78
#          ... OCR page 6/78
#          ... OCR page 8/78
#          ... OCR page 10/78
#          ... OCR page 12/78
#          ... OCR page 14/78
#          ... OCR page 16/78
#          ... OCR page 18/78
#          ... OCR page 20/78
#          ... OCR page 22/78
#          ... OCR page 24/78
#          ... OCR page 26/78
#          ... OCR page 28/78
#          ... OCR page 30/78
#          ... OCR page 32/78
#          ... OCR page 34/78
#          ... OCR page 36/78
#          ... OCR page 38/78
#          ... OCR page 40/78
#          ... OCR page 42/78
#          ... OCR page 44/78
#          ... OCR page 46/78
#          ... OCR page 48/78
#          ... OCR page 50/78
#          ... OCR page 52/78
#          ... OCR page 54/78
#          ... OCR page 56/78
#          ... OCR page 58/78
#          ... OCR page 60/78
#          ... OCR page 62/78
#          ... OCR page 64/78
#          ... OCR page 66/78
#          ... OCR page 68/78
#          ... OCR page 70/78
#          ... OCR page 72/78
#          ... OCR page 74/78
#          ... OCR page 76/78
#          ... OCR page 78/78
#    - [70/75] Policijos licencijuojamos veiklos informacinė sistema
#          ... OCR page 2/59
#          ... OCR page 4/59
#          ... OCR page 6/59
#          ... OCR page 8/59
#          ... OCR page 10/59
#          ... OCR page 12/59
#          ... OCR page 14/59
#          ... OCR page 16/59
#          ... OCR page 18/59
#          ... OCR page 20/59
#          ... OCR page 22/59
#          ... OCR page 24/59
#          ... OCR page 26/59
#          ... OCR page 28/59
#          ... OCR page 30/59
#          ... OCR page 32/59
#          ... OCR page 34/59
#          ... OCR page 36/59
#          ... OCR page 38/59
#          ... OCR page 40/59
#          ... OCR page 42/59
#          ... OCR page 44/59
#          ... OCR page 46/59
#          ... OCR page 48/59
#          ... OCR page 50/59
#          ... OCR page 52/59
#          ... OCR page 54/59
#          ... OCR page 56/59
#          ... OCR page 58/59
#    - [71/75] Elektros energijos kainų palyginimo informacinė sistema
#          ... OCR page 2/35
#          ... OCR page 4/35
#          ... OCR page 6/35
#          ... OCR page 8/35
#          ... OCR page 10/35
#          ... OCR page 12/35
#          ... OCR page 14/35
#          ... OCR page 16/35
#          ... OCR page 18/35
#          ... OCR page 20/35
#          ... OCR page 22/35
#          ... OCR page 24/35
#          ... OCR page 26/35
#          ... OCR page 28/35
#          ... OCR page 30/35
#          ... OCR page 32/35
#          ... OCR page 34/35
#    - [72/75] Išmanioji mokesčių administravimo informacinė sistema
#          ... OCR page 2/93
#          ... OCR page 4/93
#          ... OCR page 6/93
#          ... OCR page 8/93
#          ... OCR page 10/93
#          ... OCR page 12/93
#          ... OCR page 14/93
#          ... OCR page 16/93
#          ... OCR page 18/93
#          ... OCR page 20/93
#          ... OCR page 22/93
#          ... OCR page 24/93
#          ... OCR page 26/93
#          ... OCR page 28/93
#          ... OCR page 30/93
#          ... OCR page 32/93
#          ... OCR page 34/93
#          ... OCR page 36/93
#          ... OCR page 38/93
#          ... OCR page 40/93
#          ... OCR page 42/93
#          ... OCR page 44/93
#          ... OCR page 46/93
#          ... OCR page 48/93
#          ... OCR page 50/93
#          ... OCR page 52/93
#          ... OCR page 54/93
#          ... OCR page 56/93
#          ... OCR page 58/93
#          ... OCR page 60/93
#          ... OCR page 62/93
#          ... OCR page 64/93
#          ... OCR page 66/93
#          ... OCR page 68/93
#          ... OCR page 70/93
#          ... OCR page 72/93
#          ... OCR page 74/93
#          ... OCR page 76/93
#          ... OCR page 78/93
#          ... OCR page 80/93
#          ... OCR page 82/93
#          ... OCR page 84/93
#          ... OCR page 86/93
#          ... OCR page 88/93
#          ... OCR page 90/93
#          ... OCR page 92/93
#          ... OCR page 2/93
#          ... OCR page 4/93
#          ... OCR page 6/93
#          ... OCR page 8/93
#          ... OCR page 10/93
#          ... OCR page 12/93
#          ... OCR page 14/93
#          ... OCR page 16/93
#          ... OCR page 18/93
#          ... OCR page 20/93
#          ... OCR page 22/93
#          ... OCR page 24/93
#          ... OCR page 26/93
#          ... OCR page 28/93
#          ... OCR page 30/93
#          ... OCR page 32/93
#          ... OCR page 34/93
#          ... OCR page 36/93
#          ... OCR page 38/93
#          ... OCR page 40/93
#          ... OCR page 42/93
#          ... OCR page 44/93
#          ... OCR page 46/93
#          ... OCR page 48/93
#          ... OCR page 50/93
#          ... OCR page 52/93
#          ... OCR page 54/93
#          ... OCR page 56/93
#          ... OCR page 58/93
#          ... OCR page 60/93
#          ... OCR page 62/93
#          ... OCR page 64/93
#          ... OCR page 66/93
#          ... OCR page 68/93
#          ... OCR page 70/93
#          ... OCR page 72/93
#          ... OCR page 74/93
#          ... OCR page 76/93
#          ... OCR page 78/93
#          ... OCR page 80/93
#          ... OCR page 82/93
#          ... OCR page 84/93
#          ... OCR page 86/93
#          ... OCR page 88/93
#          ... OCR page 90/93
#          ... OCR page 92/93
#    - [73/75] Sveikatos priežiūros technologijų, susijusių su medicinos prietaisais, valdymo informacinė sistema
#          ... OCR page 2/44
#          ... OCR page 4/44
#          ... OCR page 6/44
#          ... OCR page 8/44
#          ... OCR page 10/44
#          ... OCR page 12/44
#          ... OCR page 14/44
#          ... OCR page 16/44
#          ... OCR page 18/44
#          ... OCR page 20/44
#          ... OCR page 22/44
#          ... OCR page 24/44
#          ... OCR page 26/44
#          ... OCR page 28/44
#          ... OCR page 30/44
#          ... OCR page 32/44
#          ... OCR page 34/44
#          ... OCR page 36/44
#          ... OCR page 38/44
#          ... OCR page 40/44
#          ... OCR page 42/44
#          ... OCR page 44/44
#    - [74/75] Švietimo įstaigų (išskyrus aukštąsias mokyklas) vadovų informacinė sistema
#          ... OCR page 2/39
#          ... OCR page 4/39
#          ... OCR page 6/39
#          ... OCR page 8/39
#          ... OCR page 10/39
#          ... OCR page 12/39
#          ... OCR page 14/39
#          ... OCR page 16/39
#          ... OCR page 18/39
#          ... OCR page 20/39
#          ... OCR page 22/39
#          ... OCR page 24/39
#          ... OCR page 26/39
#          ... OCR page 28/39
#          ... OCR page 30/39
#          ... OCR page 32/39
#          ... OCR page 34/39
#          ... OCR page 36/39
#          ... OCR page 38/39
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P208' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P214' is an invalid float value
#    - [75/75] Nėščiųjų, gimdyvių ir naujagimių sveikatos duomenų tvarkymo informacinė sistema
#          ... OCR page 2/36
#          ... OCR page 4/36
#          ... OCR page 6/36
#          ... OCR page 8/36
#          ... OCR page 10/36
#          ... OCR page 12/36
#          ... OCR page 14/36
#          ... OCR page 16/36
#          ... OCR page 18/36
#          ... OCR page 20/36
#          ... OCR page 22/36
#          ... OCR page 24/36
#          ... OCR page 26/36
#          ... OCR page 28/36
#          ... OCR page 30/36
#          ... OCR page 32/36
#          ... OCR page 34/36
#          ... OCR page 36/36
#    -> Saved batch 3 checkpoint: registrai_output_texts_part3.json
#
# Done. Wrote merged texts and JSON to registrai_output_texts.json

# %%
import os
import shutil
import glob

# -------- Settings --------
REPO_NAME = "final_information_modeling_individual_task"
REPO_DIR  = REPO_NAME 
FOLDERS   = ["downloaded_articles", "downloaded_articles_txt"]

# 1) Recreate the repo directory
if os.path.exists(REPO_DIR):
    shutil.rmtree(REPO_DIR)
    print(f"Cleared existing '{REPO_DIR}' directory.")
os.makedirs(REPO_DIR, exist_ok=True)
print(f"Created '{REPO_DIR}' directory.")

# 2) Copy the folders
for folder in FOLDERS:
    if os.path.isdir(folder):
        dest = os.path.join(REPO_DIR, os.path.basename(folder))
        print(f"Copying folder: {folder} -> {dest}")
        shutil.copytree(folder, dest)
    else:
        print(f"Skipping (not found): {folder}")

# 3) Copy all JSON files
json_files = glob.glob("*.json")
if json_files:
    for jf in json_files:
        dest = os.path.join(REPO_DIR, os.path.basename(jf))
        print(f"Copying JSON: {jf} -> {dest}")
        shutil.copy2(jf, dest)
else:
    print("No .json files found.")

# 4) Zip the repo folder (no auto-download)
zip_base = os.path.abspath(REPO_DIR)
zip_path = shutil.make_archive(zip_base, "zip", root_dir=".", base_dir=REPO_DIR)

print("\nAll set!")
print(f"Repo folder: {os.path.abspath(REPO_DIR)}")
print(f"Zip archive: {zip_path}")
# Out:
# Created 'final_information_modeling_individual_task' directory.
# Copying folder: downloaded_articles -> final_information_modeling_individual_task/downloaded_articles
# Copying folder: downloaded_articles_txt -> final_information_modeling_individual_task/downloaded_articles_txt
# Copying JSON: registrai_output_with_docs.json -> final_information_modeling_individual_task/registrai_output_with_docs.json
# Copying JSON: registrai_output_texts_part2.json -> final_information_modeling_individual_task/registrai_output_texts_part2.json
# Copying JSON: registrai_output_texts_part3.json -> final_information_modeling_individual_task/registrai_output_texts_part3.json
# Copying JSON: registrai_output.json -> final_information_modeling_individual_task/registrai_output.json
# Copying JSON: registrai_output_texts.json -> final_information_modeling_individual_task/registrai_output_texts.json
# Copying JSON: registrai_output_texts_part1.json -> final_information_modeling_individual_task/registrai_output_texts_part1.json
#
# All set!
# Repo folder: /content/final_information_modeling_individual_task
# Zip archive: /content/final_information_modeling_individual_task.zip
